# %%
#command prompt steps to activate coreNLP
    #cd C:\Users\james\Downloads\stanford-corenlp-4.5.6
    #java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
import nltk
from nltk.tokenize import sent_tokenize
import openpyxl
from openpyxl import load_workbook
from openpyxl.utils import get_column_letter
import re
from nltk.parse.corenlp import CoreNLPParser
from nltk.parse.corenlp import CoreNLPDependencyParser
from nltk import Tree
from nltk.draw.util import CanvasFrame
from nltk.draw import TreeWidget
import sys
import os
from docx import Document
from docx.enum.text import WD_COLOR_INDEX
import glob
import io
import numpy as np
import requests
import itertools
import pandas as pd
import shutil
parser = CoreNLPParser(url='http://localhost:9000')

# %% [markdown]
# # SENTENCE_TREE CLASS

# %%
class sentence_tree:
    """
    The sentence_tree class is a collection of functions and variables to perform operations and collect 
    statistics on a sentence respectively
    """

    def __init__(self, sentence):
        
        """
        This function initializes my class
        
        INPUT:
            sentence - sentence string to process
        """
        self.sentence = sentence
        self.tree = next(parser.raw_parse(self.sentence))
        self.parse_tuples = self.tree_to_tuples(self.tree)
        self.position_in_sentence = [0] #variable to keep track of position in sentence through recursions
        self.indexed_tuples =  self.create_indexed_tuples(self.parse_tuples,  self.position_in_sentence)
        self.prune_tree = [[]]#This stores all the trees with NPs in the sentence
        self.Noun_List = ["NN","NNS","NNP","NNPS"] #this stores all parts of speech that can be treated as a noun phrase
        self.Noun_Phrases = ['NP','NP-TMP','WHNP'] #list of all noun phrases
        self.Prepositional_Phrase = ["PP"] #List of Prepositional phrase markers (just one)
        self.Sentence = ["S"] #list of sentence markers (just one in this case)
        self.preposition_or_subordinating_conjunction = ["IN"] #list of prepositions or subordinating conjunctions
        self.unnecessary_fluff = ["SBAR","TO", "S"] #temporary fix for bigger phrases that are definietely different NPs

    

    def tree_to_tuples(self, tree):
        """
            Create nltk tree from sentence
            
            INPUT:
                tree - tuple tree
            OUTPT:
                nltk.Tree object created from tree
        """
        if isinstance(tree, nltk.Tree):
            return (tree.label(), [self.tree_to_tuples(t) for t in tree])
        else:
            return tree

    def flatten_list(self, input_list):
        flattened = []
        for item in input_list:
            if isinstance(item, list):
                flattened.extend(self.flatten_list(item))  # Recursively flatten the list
            else:
                flattened.append(item)  # Append the string or non-list item directly
        return flattened

    def is_sublist(self, sub_list, main_list, keep = False):
        len_sub = len(sub_list)
        if not keep:
            if len_sub == len(main_list):
                return False
        for i in range(len(main_list) - len_sub + 1):
            if main_list[i:i + len_sub] == sub_list:
                return True
        return False
    
    def create_indexed_tuples(self, tree, position):
        """
        Create a tuple tree that replaces the word in the leaves with a list [word, position in sentence]
        
        INPUT:
            tree - tuple tree
            position - list to hold value of the position in string through recursions
        """
        if isinstance(tree, tuple):
            label, children = tree
            new_children = []
            for child in children:
                new_children.append(self.create_indexed_tuples(child, position))
            return (label, new_children)
        else:
            position[0] += 1
            return ({'word' : tree, 'position' : position[0]})
    
    def prune_to_np_branches(self, tree):
        """
        Function wrapper to call prune_general specifically to collect NPs
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            assignment to self.prune_tree of the list of NP strings
        """
        
        self.prune_tree = [[]]
        self.prune_general(tree, self.prune_tree, PoS = ['NP','NP-TMP','WHNP'])
        
    def prune_general(self, tree, tree2, PoS = ['NP','NP-TMP','WHNP']):
        """
        General case function for collecting the trees assosciated with a part of speech, PoS, for the tuple tree
        in tree and collecting them in tree 2
        INPUT:
            tree  - a tuple tree
            tree2 - a list of a list of tuple trees containing part of speech being searched for. 
                    It is a list so that the list of tuples can be appended in every recursive call.  
            PoS   - the part of speech that is being collected in tree2.  The default is Noun Phrase (NP)
        OUTPUT:
            modifies tree2 to store on the parts of speech specified by PoS for the sentence (in the form of a list of tuple trees) in tree
            The return value is None this signifies the last tuple (string, list) has been reached
        
        """
        if isinstance(tree, tuple): #Check that tree is a tuple tree and not a list
            label, children = tree #extracts the string and list from the tuple 
            """
            print("label:",label)
            print("children:",children)
            print()
            """
            if label in PoS:
                # If it's a node matching the part of speech save it to tree2
                tree2[0].append(tree) 
            if isinstance(children, list):#check if children is a path (list) and not a string
                # Recursively check children; keep those leading to an NP
                """
                for child in children:
                    print("child: ", child)
                    print()
                """
                for child in children:
                    np_children = self.prune_general(child, tree2, PoS = self.Noun_Phrases) #process each path in the tree
        return None
    
    def Does_Tree_Have_Target(self, tree, target = ['NP','NP-TMP','WHNP']): 
        """
        Check if a tree has the target part of speech (Either Posessive or NP)
        INPUT:
        tree  - tuple tree being scanned
        target - part of speech being targeted, default NP
        """
        recursion_for_target = False
        if isinstance(tree, tuple): #check if tree is in (string label, path list) form
            label, children = tree
            if label in target: #doesnt have to be NP, can be varialbe that can be assigned either as NP or POS
                return True
            else:
                for ii, child in enumerate(children):
                    if child[0] == target:
                        return True
                    else:
                        if self.Does_Tree_Have_Target(child, target):
                            recursion_for_target = True
        if recursion_for_target:
            return True
        else:
            return False
    
    """
    def Trees_without_NPs(self, tree):
        self.prune_tree = []
        Trees_without_NPs_List = []
        self.prune_to_np_branches(tree)
        for p_tree in self.prune_tree:
            if not self.Does_Tree_Have_Target(("Root",p_tree[1])):
                Trees_without_NPs_List.append(p_tree)
        return Trees_without_NPs_List
    """
    
    
    
    def tree_to_string_no_labels(self, tree, is_indexed = False):
        """
        Convert a tuple tree to the sentence string it represents
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            this function is recursive so it returns a tuple tree if it is still processing a tree,
            otherwise it returns a string with all of the substrings appended together
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple): #and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return " ".join([self.tree_to_string_no_labels(branch, is_indexed) for branch in branches]).strip()
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return " ".join([self.tree_to_string_no_labels(leaf, is_indexed) for leaf in tree]).strip()
        # Base case: the tree is a leaf (a word)
        else:
            if is_indexed:
                return tree['word']
            else:
                return tree

    ''' DEPRICATED   
    def tree_to_string_no_labels_part_2(self, tree_list):
        """
        Convert each tree in the list to a string, excluding all grammatical labels
        
        INPUT:
            tree_list - list of tuple strings to process
        """
        tree_strings_no_labels = [self.tree_to_string_no_labels(tree) for tree in tree_list]
        return tree_strings_no_labels
    '''
    '''
    def tree_to_string_no_labels(self, tree):
        """
        Covert a tuple tree to the sentence string it represents
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            this function is recursive so it returns a tuple tree if it is still processing a tree,
            otherwise it returns a string with all of the substrings appended together
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple) and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return " ".join([self.tree_to_string_no_labels(branch) for branch in branches]).strip()
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return " ".join([self.tree_to_string_no_labels(leaf) for leaf in tree]).strip()
        # Base case: the tree is a leaf (a word)
        else:
            return tree
    '''
    def tree_to_list_of_strings(self, tree, is_indexed = False):
        """
        Convert a tree of a list of strings without grammatical labels
        
        INPUT:
            tree - tuple tree
            is_index - is the tuple tree standard (False) or have indexing (True)
        OUTPUT:
            list of the strings in the tuple tree
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple) and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return self.flatten_list([self.tree_to_list_of_strings(branch, is_indexed) for branch in branches])
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return [self.tree_to_list_of_stings(leaf, is_indexed) for leaf in tree]
        # Base case: the tree is a leaf (a word)
        else:
            if is_indexed:
                return tree['word']
            else:
                return tree

    
    def list_of_trees_to_list_of_strings(self, tree_list, is_indexed = False):
        """
        Convert each tree in a list to a string list, excluding all grammatical labels
        
        INPUT:
            list of trees
            
        OUPUT:
            list of string lists
        """
        tree_strings_no_labels = [self.tree_to_list_of_strings(tree, is_indexed) for tree in tree_list]
        return tree_strings_no_labels

    '''DEPRICATE
    def duplicate_NP_removal(self, tree, keep_substring = False):
        """
        remove strings that overlap with other strings
        
        INPUT:
            tree - tuple tree to be processed 
            keep_substring - Boolean switch to determine if substrings are kept or the containing string
                             default is False
        OUTPUT:
            list of NP tupple tree strings with overlapping strings removed
        """
        strings_with_NPs = self.tree_to_string_no_labels_part_2(tree)
        strings_with_NPs_True_Or_False_Array = [True] * len(strings_with_NPs)

        for idx,s in enumerate(strings_with_NPs):
            for idy,t in enumerate(strings_with_NPs[idx+1:]):
                if strings_with_NPs[idx] in strings_with_NPs[idy+1+idx]:
                    if keep_substring:
                        strings_with_NPs_True_Or_False_Array[idy+1+idx] = False
                    else:
                        strings_with_NPs_True_Or_False_Array[idx] = False
                elif strings_with_NPs[idy+1+idx] in strings_with_NPs[idx]:
                    if keep_substring:
                        strings_with_NPs_True_Or_False_Array[idx] = False
                    else:
                        strings_with_NPs_True_Or_False_Array[idy+1+idx] = False
        nps_without_duplicates = []
        for ii,noun_phrase in enumerate(tree):
            if strings_with_NPs_True_Or_False_Array[ii]:
                nps_without_duplicates.append(noun_phrase)
        return nps_without_duplicates
    '''
    
    def check_and_remove_PoS(self, tree, PoS = ["TO","SBAR", "S"]):
        """
        Remove trees with the chosen label and return modified tree
        
        INPUT:
           tree - tuple tree to check for PoS
           PoS - part of speech being removed from tuple tree
        OUTPUT:
            returns tuple tree with all subtree with PoS label removed
        """
        if isinstance(tree, tuple):
            # If the tuple contains 'POS', return None to signify removal
            if tree[0] in PoS:
                return None
            else:
                # Otherwise, recursively process and rebuild the tuple without 'POS'
                return (tree[0], [self.check_and_remove_PoS(sub_t, PoS) for sub_t in tree[1] if self.check_and_remove_PoS(sub_t, PoS) is not None])
        elif isinstance(tree, list):
            # For lists, filter through and only keep items that should not be removed
            return [self.check_and_remove_PoS(sub_t, PoS) for sub_t in tree if self.check_and_remove_PoS(sub_t, PoS) is not None]
        else:
            return tree

    def remove_pos_tuples(self, tree):
        """
        Function to check and remove tuples containing 'POS' and the smallest tree containing the POS (i.e. NP: Cinderella's)
        INPUT:
            tree - tuple tree to process
        OUTPUT:
            list of tuple trees with 'POS' removed
        """
        trees2compare = []
        trees_without_pos = []  # List to store trees without 'POS'

        # Separate trees with 'POS' and trees without 'POS'
        for idx, t in enumerate(tree):
            if self.Does_Tree_Have_Target(t, target=['POS']):
                trees2compare.append((idx, t))
            else:
                trees_without_pos.append(t)

        keep_trees = []
        if len(trees2compare) > 1:
            for idx, t1 in enumerate(trees2compare[:-1]):
                s1 = self.tree_to_list_of_strings(t1[1])
                for idy, t2 in enumerate(trees2compare[idx + 1:]):
                    s2 = self.tree_to_list_of_strings(t2[1])
                    if len(s1) < len(s2):
                        if self.is_sublist(s1, s2):
                            keep_trees.append(t2[0])
                    elif self.is_sublist(s2, s1):
                        keep_trees.append(t1[0])

        # Print keep_trees after identifying smallest trees containing 'POS'
        # print("Keep trees after sublist check:", keep_trees)

        # Add trees without 'POS' to the keep_trees list
        #keep_trees.extend([idx for idx, _ in enumerate(tree) if idx in keep_trees])

        # Print keep_trees after adding trees without 'POS'
        # print("Keep trees after adding trees without 'POS':", keep_trees)

        cleaned_trees = trees_without_pos
        for idx, t in enumerate(tree):
            if idx in keep_trees:
                cleaned_trees.append(t)

        # Print the final cleaned_trees
        #print("Final cleaned trees:", cleaned_trees)

        return cleaned_trees



        # Filter out any None values that may have resulted from removal
        #return [t for t in cleaned_tuples if t is not None]
    
    def case_for_complicated_NP_embeddings(self, tree_list):
        """
        Combine NPs together into one NP to catch NNs that are modified by NPs 
        
        INPUT:
            tree_list - tuple tree
        OUTPUT:
            list of NPs that have passed this criterion
        """
        def check_for_NPs(tree_list, reduced_list):
            """
            Recursive function to perform logic on the tuple tree
            
            INPUT:
                tree_list - list of np trees to compare
                reduced_list - list of the list of final NP trees to keep
            OUTPUT:
                the list of NP strings to keep is updated in reduced_list
                the return value is the list of NP strings 
            """
            for tree in tree_list:
                if isinstance(tree, tuple):
                    keep_tree = True
                    count_of_NNs = self.count_tokens([tree], self.Noun_List)
                    if count_of_NNs > 1:
                        top_level_NPs = [[]] 
                        self.prune_general(tree[1][0], top_level_NPs)
                        count_of_NPs = self.count_tokens(tree[1], self.Noun_Phrases)

                        if count_of_NPs > 1:
                            temp_list = []
                            for top_level_NP in top_level_NPs[0]:
                                count_of_NNs = self.count_tokens(top_level_NP, self.Noun_List)
                                if count_of_NNs > 0:
                                    result = check_for_NPs([top_level_NP], reduced_list)  # Ensure this is a list
                                    temp_list.extend(result)  # Extend flattens the list
                            reduced_list[0].extend(temp_list)
                            keep_tree = False
                    count_of_unnecessary_fluff = self.count_tokens([tree], self.unnecessary_fluff)
                    if count_of_unnecessary_fluff >= 1:
                        tree = self.check_and_remove_PoS(tree, self.unnecessary_fluff)
                        keep_tree = True
                    count_of_PPs = self.count_tokens([tree], self.Prepositional_Phrase)
                    if count_of_PPs >= 1:
                        keep_tree = False
                    count_of_Ss = self.count_tokens([tree], self.Sentence)
                    if count_of_Ss >= 1:
                        keep_tree = False
                    count_of_INs = self.count_tokens([tree], self.preposition_or_subordinating_conjunction)
                    if count_of_INs >= 1:
                        keep_tree = False
                    if keep_tree:
                        reduced_list[0].append(tree)

        NPs_that_pass_this_function = [[]]
        NP_check = check_for_NPs(tree_list, NPs_that_pass_this_function)

        # Remove duplicates based on leaves
        unique_nps = []
        seen_leaves = set()
        for np in NPs_that_pass_this_function[0]:
            leaves = tuple(self.extract_leaves(np))  # Convert leaves to a tuple for hashing
            if leaves not in seen_leaves:
                seen_leaves.add(leaves)
                unique_nps.append(np)
        
        NPs_that_pass_this_function[0] = unique_nps

        return NPs_that_pass_this_function
     
    def count_tokens(self, tree_list, tokens): #this can count tokens, can be used when just wanting to find certain POS such as DET, CONJ, PP etc.
        """
        Count the number of tokens occuring in the tuple tree list
        
        INPUT:
            tree_list - the tupple tree list to be processed
            tokens - the list of tokens in the tuple_tree to be counted
        OUTPUT:
            the number of times the token occurs in the tree list            
        """
        count = 0
        for item in tree_list:
            if isinstance(item, tuple):
                tag, value = item
                if tag in tokens:
                    count += 1  # Increment count for each 'token'
                elif isinstance(value, list):
                    count += self.count_tokens(value, tokens)  # Recurse into nested lists
        return count
    
    def handle_special_phrases(self, special_phrases, utterance):
        """
        Increase the prenominal modifier count if any of the specified special phrases
        are present in the utterance.

        Args:
            special_phrases (list): A list of strings representing special phrases.
            utterance (str): The utterance or sentence string.

        Returns:
            int: The additional prenominal modifier count to be added.
        """
        additional_count = 0
        for phrase in special_phrases:
            if phrase in utterance:
                additional_count += 1
                print(f"Prenominal Quantifier '{phrase}' found.")
                print("Prenominal No for Quantifier: 1")
        #print("Additional Count Number:",additional_count)
        return additional_count
    # Define the function to extract leaves from the tree (same as before)
    def extract_leaves(self, tree):
        leaves = []  # List to collect leaves

        def traverse(node):
            if isinstance(node, tuple) and len(node) > 1 and isinstance(node[1], list):
                if all(isinstance(item, tuple) for item in node[1]):
                    for item in node[1]:
                        traverse(item)
                else:
                    leaves.extend([(node[0], subitem) for subitem in node[1]])
            elif isinstance(node, list):
                for subnode in node:
                    traverse(subnode)

        traverse(tree)
        return leaves

# %% [markdown]
# # ALL FILES CODE

# %%
# Define the function to extract leaves from the tree (same as before)
def extract_leaves(tree):
    leaves = []  # List to collect leaves

    def traverse(node):
        if isinstance(node, tuple) and isinstance(node[1], list):
            if all(isinstance(item, tuple) for item in node[1]):
                for item in node[1]:
                    traverse(item)
            else:
                leaves.extend([(node[0], subitem) for subitem in node[1]])
        elif isinstance(node, list):
            for subnode in node:
                traverse(subnode)

    traverse(tree)
    return leaves

# Define the function to scan modifiers (same as before)
def scan_modifiers(leaves, special_phrases):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC", "TO", "IN", "POS", "CC", "RP"]
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals  # Include 'been' in the exclusions
    CC_pos = ["CC"]

    # Add the specific prenominal quantifier phrases to exclude
    Prenominal_Quantifier_Words = ['many', 'all', 'most', 'some', 'few', 'several', 'number', 'bit', "lot","bunch", "any", "one"]

    # Count modifiers that are not in the excluded lists
    modifier_count = 0

    for ii, (pos, word) in enumerate(leaves[-2::-1]):  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            # Check for prenominal quantifier phrases
            if word in Prenominal_Quantifier_Words and ii + 1 < len(leaves) and leaves[-ii-2][1] == 'of':
                continue  # Skip the word if it is part of a prenominal quantifier phrase
            
            # Check if the current leaf contains a special phrase
            leaf_phrase = ' '.join(leaf[1] for leaf in leaves[-ii - 2:])
            if any(special_phrase in leaf_phrase for special_phrase in special_phrases):
                continue  # Skip if it matches any special phrase
            
            # Increment the modifier count
            modifier_count += 1

        if pos in CC_pos:
            if ii + 1 < len(leaves) and leaves[-ii-1][0] in All_Nouns:
                modifier_count -= 1
                continue
            elif ii + 2 < len(leaves) and leaves[-ii-2][0] == "DT":
                break

    return modifier_count

# Define lists of POS tags and specific words to be considered or excluded (same as before)
All_Nouns = ["NN", "NNS", "NNP", "NNPS"]
All_Adjectives = ["JJ", "JJR", "JJS", "PRP$"]
All_Adverbs = ["RB", "RBR", "RBS"]
Verbs_that_can_be_prenominal = ["VBN"]
Determiners_to_be_excluded_as_prenominals = ["a", "A", "an", "An", "the", "The", "that", "That", "these", "These", "those", "Those", "this", "This", "either", "Either", "around", "Around"]
Words_to_be_excluded_as_prenominals = ["been","around", "almost", "never","behind","above","whose","which"]
Prenominal_Quantifier_Phrases = ['a lot of', 'many of', 'all of', 'most of', 'some of', 'a few of', 'several of', 'a number of', 'a bit of', 'a bunch of', "any of", "one of"]

# Directory mapping (same as before)
# Define source directories and corresponding destination directories
directory_mapping = {
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\older adult cinderella individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\older adult cinderella individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\older adult hobby individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\older adult hobby individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\young adult cinderella individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\young adult cinderella individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\young adult hobby individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\young adult hobby individual sentences"
}

# Ensure destination directories exist (same as before)
for dest in directory_mapping.values():
    os.makedirs(dest, exist_ok=True)

# Define the function to process Excel files
def process_excel_file(src_file_path, dest_file_path):
    # Load the workbook and worksheet
    wb = load_workbook(src_file_path)
    ws = wb.active

    # Find the last row with data in column B
    last_row = ws.max_row
    last_row_formulas = {}  # Dictionary to store formulas in the last row

    for col in range(2, ws.max_column + 1):
        col_letter = get_column_letter(col)
        # Check if the header is "Comments"
        if ws[f'{col_letter}1'].value == "Comments":
            continue
        # Calculate the sum of values in the column (excluding the header)
        column_sum = 0
        for row in range(2, last_row + 1):
            cell_value = ws[f'{col_letter}{row}'].value
            if isinstance(cell_value, (int, float)):
                column_sum += cell_value
            elif cell_value == 'N/A':
                continue
        # Check if the last row contains a string that starts with "=SUM"
        last_row_value = ws[f'{col_letter}{last_row}'].value
        if isinstance(last_row_value, str) and last_row_value.startswith("=SUM"):
            last_row_formulas[col_letter] = last_row_value
        elif not isinstance(last_row_value, str) or not last_row_value.startswith("=SUM"):
            next_row = last_row + 1
            ws[f'{col_letter}{next_row}'] = column_sum
    
    # Save the file to the specified destination path
    wb.save(dest_file_path)
    
    # Load the processed data into pandas for further manipulation
    data = pd.read_excel(dest_file_path)

    # Data manipulation logic (same as before, ensuring that formula rows are preserved)
    data.insert(1, 'Prenominal Modifiers', '')

    for index, row in data.iterrows():
        utterance = row['UTTERANCES']
        if pd.isna(utterance) or utterance.strip() == '':
            continue  # Skip this iteration if the cell is blank or empty
        
        utterance = utterance.replace("[+ 0subj]", "").replace("[+ gram]", "").replace("0det", "").replace("[e]", "")
        print(f"Utterance: {utterance}")

        sentence_class = sentence_tree(utterance)
        special_phrase_count = sentence_class.handle_special_phrases(Prenominal_Quantifier_Phrases, utterance)
        sentence_class.prune_to_np_branches(sentence_class.parse_tuples)
        nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])
        nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)
        total_modifiers = 0
        for tree in nps_factored_for_complicated_NP_embedding[0]:
            leaves = extract_leaves(tree)
            modifier_count = scan_modifiers(leaves, Prenominal_Quantifier_Phrases)
            total_modifiers += modifier_count
            if modifier_count > 0:  # Change to >0 when debugging
                print()
                print("Extracted Phrase:", leaves)
                print(f"Prenominal No: {modifier_count}")
        total_modifiers += special_phrase_count
        print()
        print(f"Total No: {total_modifiers}")
        data.at[index, 'Prenominal Modifiers'] = total_modifiers

    data['Prenominal Modifiers'] = pd.to_numeric(data['Prenominal Modifiers'], errors='coerce')
    data['Prenominal Modifiers'].fillna(0, inplace=True)

    # Save the DataFrame back to Excel
    data.to_excel(dest_file_path, index=False)

    # Reload the workbook to reapply formulas
    wb = load_workbook(dest_file_path)
    ws = wb.active
    last_row = len(data) + 1
    ws[f'B{last_row}'] = f"=SUM(B2:B{last_row-1})"
    next_row = last_row + 1
    ws[f'A{next_row}'] = "Prenominal Modifiers/#Nouns"
    ws[f'B{next_row}'] = f"=B{last_row}/G{last_row}"
    wb.save(dest_file_path)

# %%
# Loop through each directory and process each file
for src_directory, dest_directory in directory_mapping.items():
    excel_files = glob.glob(os.path.join(src_directory, '*.xlsx'))
    for file_path in excel_files:
        file_name = os.path.basename(file_path)
        base_name = os.path.splitext(file_name)[0]
        dest_file_path = os.path.join(dest_directory, file_name)
        print(f"File: {base_name}")
        process_excel_file(file_path, dest_file_path)

print("All files processed successfully.")
# Out:
# File: 38o9ts7l.cqp.AS
# Utterance: Cinderella is about a young girl who has some stepsisters .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'girl')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'some'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: she is having to clean the house and do all the chores .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NNS', 'chores')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she is not included in a lot of things .
# Prenominal Quantifier 'a lot of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: they are going to have a party .
#
# Total No: 0
# Utterance: a ball is going to happen .
#
# Total No: 0
# Utterance: all the stepsisters are invited to attend .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she has to help them find their clothes .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'clothes')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the stepmother is not going to allow Cinderella to attend .
#
# Total No: 0
# Utterance: she does get to go .
#
# Total No: 0
# Utterance: her fairy godmother comes and creates a beautiful dress for her and a carriage for her to ride in .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'dress')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: she goes to the ball and falls in love with the prince .
#
# Total No: 0
# Utterance: she has to leave .
#
# Total No: 0
# Utterance: she loses her slipper .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she gets in her carriage to get back home before it turns back into a pumpkin .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'carriage')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the prince really wants to find her .
#
# Total No: 0
# Utterance: he takes this lost slipper .
#
# Extracted Phrase: [('DT', 'this'), ('VBN', 'lost'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he goes around .
#
# Total No: 0
# Utterance: he tries it on everybody .
#
# Total No: 0
# Utterance: all of the stepsisters want to wear the slipper .
# Prenominal Quantifier 'all of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: they do not fit in it .
#
# Total No: 0
# Utterance: the slipper fits on her .
#
# Total No: 0
# Utterance: magically she gets to live happily with the prince .
#
# Total No: 0
# File: 56uzk3n3.cqp.AS
# Utterance: she is the stepdaughter .
#
# Total No: 0
# Utterance: her mother had married her father .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'mother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'father')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: her father had passed away .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'father')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: her stepmother had three other daughters .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'three'), ('JJ', 'other'), ('NNS', 'daughters')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: because she was just a stepdaughter her stepmother did not treat her as a real daughter and basically treated her as a servant .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'real'), ('NN', 'daughter')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: she had to take care of the needs of all of her stepsisters who treated her very badly .
# Prenominal Quantifier 'all of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: one day there was a announcement that the prince was throwing this ball .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'day')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he is looking for a new wife .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'new'), ('NN', 'wife')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: her three stepsisters all thought they had a chance of getting the prince .
#
# Extracted Phrase: [('PRP$', 'her'), ('CD', 'three'), ('NNS', 'stepsisters')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: they dressed in their finest clothes .
#
# Extracted Phrase: [('PRP$', 'their'), ('JJS', 'finest'), ('NNS', 'clothes')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she assisted them .
#
# Total No: 0
# Utterance: she was not going to be allowed to go to the party .
#
# Total No: 0
# Utterance: they left to go to the party .
#
# Total No: 0
# Utterance: she was left alone .
#
# Total No: 0
# Utterance: she got a visitation from her fairy godmother who said that she could help her get to the party and meet the prince .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she found some mice .
#
# Extracted Phrase: [('DT', 'some'), ('NNS', 'mice')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: transformed them into horses .
#
# Total No: 0
# Utterance: a pumpkin into a chariot .
#
# Total No: 0
# Utterance: gave her all these beautiful clothes .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'these'), ('JJ', 'beautiful'), ('NNS', 'clothes')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she was able to travel to the ball whereupon when the prince first laid eyes upon her he thought she was most beautiful .
#
# Total No: 0
# Utterance: led her to the ball .
#
# Total No: 0
# Utterance: they danced all night .
#
# Extracted Phrase: [('DT', 'all'), ('NN', 'night')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she had to get back home by midnight .
#
# Total No: 0
# Utterance: otherwise that is when the spell was going to run out .
#
# Total No: 0
# Utterance: she noticed the time was running out .
#
# Total No: 0
# Utterance: she had to flee from him .
#
# Total No: 0
# Utterance: in the process she left her glass slipper .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'glass'), ('NN', 'slipper')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she ran out .
#
# Total No: 0
# Utterance: he could not find her again .
#
# Total No: 0
# Utterance: he did find her glass slippers .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'glass'), ('NNS', 'slippers')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: the next day he searched throughout the kingdom looking for the woman whose foot would fit the slipper .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'next'), ('NN', 'day')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he visited her family's house .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'family'), ('POS', "'s"), ('NN', 'house')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: her stepmother hid her away but had her three daughters try on the slipper .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('CD', 'three'), ('NNS', 'daughters')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: their feet could not fit into her slippers .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'feet')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'slippers')]
# Prenominal No: 1
#
# Total No: 2
# File: 5838wegd.cqp.AS
# Utterance: Cinderella was a little housemaid .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'little'), ('NN', 'housemaid')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she had three ugly stepsisters .
#
# Extracted Phrase: [('CD', 'three'), ('JJ', 'ugly'), ('NNS', 'stepsisters')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: they were getting ready to go to a ball .
#
# Total No: 0
# Utterance: she had to help them get ready to go to a ball .
#
# Total No: 0
# Utterance: she was the chambermaid .
#
# Total No: 0
# Utterance: they were getting ready to go to a ball with the handsome prince who was looking for a wife .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'handsome'), ('NN', 'prince')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she helped them get ready for the ball .
#
# Total No: 0
# Utterance: she was wanting to go .
#
# Total No: 0
# Utterance: she was the lowly chambermaid so she was not able to go .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'lowly'), ('NN', 'chambermaid')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she wished for a fairy godmother to help her to go to the ball .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: a fairy godmother appeared and gave her a wish and helped her get ready for the ball and turned the mice into horses and turned a pumpkin into a chariot .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she was able to get into a fancy dress and glass slippers .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'fancy'), ('NN', 'dress')]
# Prenominal No: 1
#
# Extracted Phrase: [('NN', 'glass'), ('NNS', 'slippers')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: she was able to go to the ball and dance with the prince .
#
# Total No: 0
# Utterance: she had to leave by midnight or she would turn back into the chambermaid and the horses would turn back into mice and the chariot would turn back into a pumpkin .
#
# Total No: 0
# Utterance: she left her slipper as she was running away at midnight .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the prince went looking for the girl and went around to try on the slipper on all the single women in the kingdom .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('JJ', 'single'), ('NNS', 'women')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: he tried it on the ugly stepsisters .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'ugly'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: it did not fit them .
#
# Total No: 0
# Utterance: he found Cinderella .
#
# Total No: 0
# Utterance: it fit her .
#
# Total No: 0
# Utterance: they lived happily .
#
# Total No: 0
# File: 6275d2er.cqp.AS
# Utterance: Cinderella had a stepmother and two stepsisters .
#
# Extracted Phrase: [('CD', 'two'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they treated her really bad .
#
# Total No: 0
# Utterance: she had to clean .
#
# Total No: 0
# Utterance: she had to sleep in the kitchen .
#
# Total No: 0
# Utterance: they got an invitation to the Prince's castle .
#
# Extracted Phrase: [('DT', 'the'), ('NNP', 'Prince'), ('POS', "'s"), ('NN', 'castle')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she had to help them get ready for the party .
#
# Total No: 0
# Utterance: she was left behind .
#
# Total No: 0
# Utterance: when they had gone to the party  Fairy godmother appeared and told her that she was going to get to go to the party .
#
# Extracted Phrase: [('NNP', 'Fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she did not have a dress .
#
# Total No: 0
# Utterance: the fairy godmother transformed her .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: put her in a beautiful dress .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'dress')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: turned the pumpkin into a stage coach .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'stage'), ('NN', 'coach')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the mice into footman .
#
# Total No: 0
# Utterance: the horses carried her to the ball .
#
# Total No: 0
# Utterance: When she got there no one knew who she was .
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'one')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the prince was mesmerized by her and asked her to dance .
#
# Total No: 0
# Utterance: at the stroke of midnight she had to leave before she turned back into herself and everything turned back .
#
# Total No: 0
# Utterance: as she was racing down the stairs she left her shoe behind .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'shoe')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the prince wanted to find her .
#
# Total No: 0
# Utterance: He tried the shoe on the feet of all these different women and went all around trying to find who fit into the shoe .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'these'), ('JJ', 'different'), ('NNS', 'women')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: he came to the house where Cinderella lived with her stepmother and stepsisters .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'stepmother'), ('CC', 'and'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they tried it on .
#
# Total No: 0
# Utterance: did not fit any of them .
# Prenominal Quantifier 'any of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: he saw her as he was leaving .
#
# Total No: 0
# Utterance: I want her to try it on .
#
# Total No: 0
# Utterance: she tried it on .
#
# Total No: 0
# Utterance: it fit .
#
# Total No: 0
# Utterance: she was transformed back into the dress that she was wearing when they met .
#
# Total No: 0
# Utterance: whoever fits this shoe I want to marry .
#
# Total No: 0
# Utterance: they got married .
#
# Total No: 0
# File: 6m1hvlzm.cqp.AS
# Utterance: This is the story of Cinderella .
#
# Total No: 0
# Utterance: Cinderella lived with her stepsisters and stepmother and was not on the equal standing with the rest of her sisters .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'stepsisters'), ('CC', 'and'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'equal'), ('NN', 'standing')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'sisters')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: she was made to do all the work in the house and was frowned upon by her family .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NN', 'work')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'family')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: there was an edict in the land that the prince was having a ball .
#
# Total No: 0
# Utterance: he was inviting all the eligible women to come to the ball .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('JJ', 'eligible'), ('NNS', 'women')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: the stepsisters were so excited .
#
# Total No: 0
# Utterance: they were going to have new gowns .
#
# Extracted Phrase: [('JJ', 'new'), ('NNS', 'gowns')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they were going to go to the ball .
#
# Total No: 0
# Utterance: Cinderella thought maybe she could go too because she was a woman who lived in the kingdom .
#
# Total No: 0
# Utterance: she was invited too .
#
# Total No: 0
# Utterance: oh no no no no you can not go .
#
# Total No: 0
# Utterance: she was disappointed as her sisters went off grandly dressed to the ball .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'sisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: a fairy godmother appeared to her .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: would you like to go to the ball .
#
# Total No: 0
# Utterance: sure .
#
# Total No: 0
# Utterance: with a whip of her magic wand she instantly had the most beautiful dress the carriage and horses that pulled her in grand fashion to the prince's castle .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'magic'), ('NN', 'wand')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'the'), ('RBS', 'most'), ('JJ', 'beautiful'), ('NN', 'dress')]
# Prenominal No: 2
#
# Extracted Phrase: [('JJ', 'grand'), ('NN', 'fashion')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('RBS', 'most'), ('JJ', 'beautiful'), ('NN', 'dress'), ('DT', 'the'), ('NN', 'carriage'), ('CC', 'and'), ('NNS', 'horses')]
# Prenominal No: 3
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'prince'), ('POS', "'s"), ('NN', 'castle')]
# Prenominal No: 1
#
# Total No: 9
# Utterance: there she was received as if she was the most elegant person there .
#
# Extracted Phrase: [('DT', 'the'), ('RBS', 'most'), ('JJ', 'elegant'), ('NN', 'person')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she was .
#
# Total No: 0
# Utterance: the prince was very smitten with her .
#
# Total No: 0
# Utterance: danced with her .
#
# Total No: 0
# Utterance: at some point in the evening her slippers which were unusual in that they were glass were admired by many people .
#
# Extracted Phrase: [('DT', 'some'), ('NN', 'point')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'slippers')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'many'), ('NNS', 'people')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: when the clock struck midnight the fairy godmother had told her that you had to leave then because everything that had been changed from the rags and riches and the pumpkins and the toads was going to change back to what they had been .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she was not going to have a carriage .
#
# Total No: 0
# Utterance: she was not going to have a fancy dress .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'fancy'), ('NN', 'dress')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: In fact she was going to look just like she did when her stepsisters left her by the fireplace .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she ran down the steps in a hurry .
#
# Total No: 0
# File: 7mytusbo.cqp.AS
# Utterance: She had lost her mother at a young age .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'mother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'age')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: her father remarried an evil stepmother who had three daughters .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'father')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'an'), ('JJ', 'evil'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'three'), ('NNS', 'daughters')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: They made her clean and cook for them .
#
# Total No: 0
# Utterance: they treated her badly even though she served them and waited on them .
#
# Total No: 0
# Utterance: One day the king's messenger came saying there would be a ball .
#
# Extracted Phrase: [('CD', 'One'), ('NN', 'day')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'king'), ('POS', "'s"), ('NN', 'messenger')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: all eligible young women should come to meet his son .
#
# Extracted Phrase: [('DT', 'all'), ('JJ', 'eligible'), ('JJ', 'young'), ('NNS', 'women')]
# Prenominal No: 3
#
# Extracted Phrase: [('PRP$', 'his'), ('NN', 'son')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: the three stepsisters put on their beautiful gowns .
#
# Extracted Phrase: [('DT', 'the'), ('CD', 'three'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'their'), ('JJ', 'beautiful'), ('NNS', 'gowns')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: Cinderella did not have a gown .
#
# Total No: 0
# Utterance: she made her own .
#
# Total No: 0
# Utterance: when it was time to go for the ball she helped the stepsisters get dressed up in their beautiful dresses .
#
# Extracted Phrase: [('PRP$', 'their'), ('JJ', 'beautiful'), ('NNS', 'dresses')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she went and put on her homemade dress .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'homemade'), ('NN', 'dress')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: when they saw it they laughed at her and tore it off of her and left without her for the ball in their carriage .
#
# Extracted Phrase: [('PRP$', 'their'), ('NN', 'carriage')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: Cinderella's fairy godmother appeared and with her wand put her in a beautiful dress and turned a pumpkin into a carriage .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'wand')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'dress')]
# Prenominal No: 1
#
# Extracted Phrase: [('NNP', 'Cinderella'), ('POS', "'s"), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: off Cinderella went to the ball .
#
# Total No: 0
# Utterance: there she caught the prince's attention .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'prince'), ('POS', "'s"), ('NN', 'attention')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they danced .
#
# Total No: 0
# Utterance: everyone was jealous .
#
# Total No: 0
# Utterance: Cinderella realized it was almost midnight when she knew the spell would be over .
#
# Total No: 0
# Utterance: she fled from the ballroom and left one of her glass slippers on the stairs .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'glass'), ('NNS', 'slippers')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: That was all the prince had to find her .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NN', 'prince')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the next day he went around to all the homes in the kingdom to find the girl whose foot fit into this slipper .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'next'), ('NN', 'day')]
# Prenominal No: 1
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NNS', 'homes')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: when he was at the Cinderella's house, the three stepsisters tried the shoe on .
#
# Extracted Phrase: [('DT', 'the'), ('CD', 'three'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NNP', 'Cinderella'), ('POS', "'s"), ('NN', 'house')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: they tried to prevent Cinderella from trying the shoe on .
#
# Total No: 0
# Utterance: at last she did .
#
# Total No: 0
# Utterance: the prince knew that he had found his wife to be .
#
# Extracted Phrase: [('PRP$', 'his'), ('NN', 'wife')]
# Prenominal No: 1
#
# Total No: 1
# File: 9rs4evla.cqp.AS
# Utterance: the story begins with Cinderella who is feeling very despondent because her mother has passed .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'mother')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she goes to live with her wicked stepmother and stepsisters .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'wicked'), ('NN', 'stepmother')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she is treated like a slave .
#
# Total No: 0
# Utterance: she has to do a lot of work around the house .
# Prenominal Quantifier 'a lot of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: she is not very happy with that arrangement .
#
# Total No: 0
# Utterance: a footman comes to the house one day saying that they are all invited to the ball .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'day')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the stepmother and the stepsisters all begin getting ready .
#
# Total No: 0
# Utterance: making preparations .
#
# Total No: 0
# Utterance: getting their outfits together .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'outfits')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: Cinderella feels left out when this is happening .
#
# Total No: 0
# Utterance: they go to the ball .
#
# Total No: 0
# Utterance: they leave without her .
#
# Total No: 0
# Utterance: her fairy godmother comes and helps her get ready .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: She changes the mice into horses .
#
# Total No: 0
# Utterance: the pumpkin into a big stagecoach .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'big'), ('NN', 'stagecoach')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they are able to go to the ball in style .
#
# Total No: 0
# Utterance: She goes .
#
# Total No: 0
# Utterance: she dances with the prince and has a wonderful time .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'wonderful'), ('NN', 'time')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: at the stroke of midnight the story comes to a halt .
#
# Total No: 0
# Utterance: the horses are about to change back into the mice .
#
# Total No: 0
# Utterance: The stagecoach is about to disappear .
#
# Total No: 0
# Utterance: she has to leave in a rush .
#
# Total No: 0
# Utterance: at that time she runs so quickly that she loses her shoe on the stairs .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'shoe')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she does make it home .
#
# Total No: 0
# Utterance: after some time the prince comes to see who is the correct owner of the glass slipper .
#
# Extracted Phrase: [('DT', 'some'), ('NN', 'time')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'correct'), ('NN', 'owner')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'glass'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: it turns out that it is Cinderella .
#
# Total No: 0
# Utterance: she lives happily with the Prince .
#
# Total No: 0
# File: a9kgfism.cqp.AS
# Utterance: There was a young girl who was a very much alone where she lived .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'girl')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she sat in the garden alone with her little red bird on her shoulder .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'little'), ('JJ', 'red'), ('NN', 'bird')]
# Prenominal No: 3
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'shoulder')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: she was expected to do the housework .
#
# Total No: 0
# Utterance: They lived in a grand home with three young women who were dressed very nicely .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'grand'), ('NN', 'home')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'three'), ('JJ', 'young'), ('NNS', 'women')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: this young girl was expected to do all the housework .
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'young'), ('NN', 'girl')]
# Prenominal No: 1
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NN', 'housework')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: you would see her sweeping the steps .
#
# Total No: 0
# Utterance: There were many steps .
#
# Extracted Phrase: [('JJ', 'many'), ('NNS', 'steps')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she was sweeping the steps .
#
# Total No: 0
# Utterance: She would sit alone in the kitchen surrounded by multiple pots and pans .
#
# Extracted Phrase: [('JJ', 'multiple'), ('NNS', 'pots'), ('CC', 'and'), ('NNS', 'pans')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the three women in the household were getting dressed for some occasion .
#
# Extracted Phrase: [('DT', 'the'), ('CD', 'three'), ('NNS', 'women')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'some'), ('NN', 'occasion')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: there were some grand ball gowns being put on .
#
# Extracted Phrase: [('DT', 'some'), ('JJ', 'grand'), ('NN', 'ball'), ('NNS', 'gowns')]
# Prenominal No: 3
#
# Total No: 3
# Utterance: she was helping them get dressed in their gowns .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'gowns')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they were off doing their thing .
#
# Extracted Phrase: [('PRP$', 'their'), ('NN', 'thing')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: they rode off in a carriage to a ball .
#
# Total No: 0
# Utterance: she was visited by some kind of a fairy godmother who might have given her some magical powers that actually got her a horse drawn carriage .
#
# Extracted Phrase: [('DT', 'some'), ('NN', 'kind')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'some'), ('JJ', 'magical'), ('NNS', 'powers')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: the other girls got to this ball .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'other'), ('NNS', 'girls')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she went separately in her magical horse drawn carriage .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'magical'), ('NN', 'horse')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she got to the ball .
#
# Total No: 0
# Utterance: there was a handsome prince .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'handsome'), ('NN', 'prince')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she went into the ball .
#
# Total No: 0
# Utterance: apparently they did notice that she was there .
#
# Total No: 0
# Utterance: she ran out at one point to escape the view of the other young women .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'point')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'other'), ('JJ', 'young'), ('NNS', 'women')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: she ran out and ran down the stairs away from this palace and lost a shoe .
#
# Total No: 0
# Utterance: she went running out .
#
# Total No: 0
# Utterance: the prince found the shoe .
#
# Total No: 0
# Utterance: he actually visited the house and went around trying to see who belonged to that shoe .
#
# Total No: 0
# Utterance: it is like the saying if the shoe fits because it fit her .
#
# Total No: 0
# Utterance: he eventually presented her with a beautiful jewel maybe a ring because this was his chosen princess .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'jewel')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'his'), ('VBN', 'chosen'), ('NN', 'princess')]
# Prenominal No: 2
#
# Total No: 3
# File: aer4zugl.cqp.AS
# Utterance: There was once a young girl who lived with her three ugly stepsisters and was made to do all the tasks of the household and even tend to the stepsister's needs .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'girl')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('CD', 'three'), ('JJ', 'ugly'), ('NNS', 'stepsisters')]
# Prenominal No: 3
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NNS', 'tasks')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'stepsister'), ('POS', "'s"), ('NNS', 'needs')]
# Prenominal No: 1
#
# Total No: 6
# Utterance: the sisters were privileged and able to attend fancy balls at the castle .
#
# Extracted Phrase: [('JJ', 'fancy'), ('NNS', 'balls')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: Cinderella could only look on enviously as they made their preparations .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'preparations')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she helped them dress and prepared to go to a fancy ball .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'fancy'), ('NN', 'ball')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: A fairy godmother came along and granted Cinderella the ability to also attend the ball by turning a pumpkin into a coach and turning rats into beautiful white horses and then creating a beautiful wardrobe for Cinderella to wear to the party .
#
# Extracted Phrase: [('DT', 'A'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'beautiful'), ('JJ', 'white'), ('NNS', 'horses')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'wardrobe')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: riding in the coach through the beautiful forest of flowers with the castle in the distance Cinderella arrives and is greeted by the prince who is wearing a crown and is pleased to meet Cinderella who he had never seen before .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'beautiful'), ('NN', 'forest')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she goes on to enjoy the party dancing with the Prince and gaining the envy and attention of everyone there including her ugly stepsisters who are angry that she is getting so much attention .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'party'), ('NN', 'dancing')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'ugly'), ('NNS', 'stepsisters')]
# Prenominal No: 2
#
# Extracted Phrase: [('RB', 'so'), ('JJ', 'much'), ('NN', 'attention')]
# Prenominal No: 2
#
# Total No: 5
# Utterance: having been told that she had to return home by midnight or else the magic would disappear when realizing that it was about to be midnight Cinderella ran off suddenly losing one of her glass slippers and leaving it behind .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('RB', 'else'), ('DT', 'the'), ('NN', 'magic')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'glass'), ('NNS', 'slippers')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: the glass slipper was the only thing that  Prince had to identify this beautiful person that he wanted very much to meet again .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'glass'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'only'), ('NN', 'thing')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'beautiful'), ('NN', 'person')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: he conducted a search of everyone in attendance at the castle .
#
# Total No: 0
# Utterance: the shoe would not fit anyone there .
#
# Total No: 0
# Utterance: they went through the village looking for the person whose foot would fit in the glass slipper giving everyone a chance to try it even the ugly sisters .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'glass'), ('NN', 'slipper')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'ugly'), ('NNS', 'sisters')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: only when Cinderella tried it did it fit her delicate foot .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'delicate'), ('NN', 'foot')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: the prince knew this was who he was looking for .
#
# Total No: 0
# Utterance: they went on to be married and as usual lived happily .
#
# Total No: 0
# File: ajcciows.cqp.AS
# Utterance: we have Cinderella there in the field .
#
# Total No: 0
# Utterance: she has her three unpleasant stepsisters .
#
# Extracted Phrase: [('PRP$', 'her'), ('CD', 'three'), ('JJ', 'unpleasant'), ('NNS', 'stepsisters')]
# Prenominal No: 3
#
# Total No: 3
# Utterance: they are kind of cruel to her and dismissive .
#
# Total No: 0
# Utterance: news of a grand ball happening .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'grand'), ('NN', 'ball')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: everybody gets excited .
#
# Total No: 0
# Utterance: the stepsisters get their big dresses ready for the big event .
#
# Extracted Phrase: [('PRP$', 'their'), ('JJ', 'big'), ('NNS', 'dresses')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'big'), ('NN', 'event')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: Cinderella is left behind .
#
# Total No: 0
# Utterance: the Fairy Godmother comes and grants her access with a magic carriage warning that she has only got a limited time before it expires .
#
# Extracted Phrase: [('DT', 'the'), ('NNP', 'Fairy'), ('NNP', 'Godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'access')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'magic'), ('NN', 'carriage'), ('NN', 'warning')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'limited'), ('NN', 'time')]
# Prenominal No: 1
#
# Total No: 5
# Utterance: she goes in .
#
# Total No: 0
# Utterance: she is a big hit at the ball but runs out of time and has to flee leaving a slipper behind on her way out .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'big'), ('NN', 'hit')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'way')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: the prince is smitten by her .
#
# Total No: 0
# Utterance: sends a guy out to search the land high and low for whoever's slipper this belongs to .
#
# Total No: 0
# Utterance: offers it around .
#
# Total No: 0
# Utterance: finally they try the unlikely prospect of this poor washer girl .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'unlikely'), ('NN', 'prospect')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'poor'), ('NN', 'washer'), ('NN', 'girl')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: it fits .
#
# Total No: 0
# Utterance: she is the magic princess .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'magic'), ('NN', 'princess')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: everybody lives happily except the jealous stepsisters .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'jealous'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# File: bmn8sa8u.cqp.AS
# Utterance: Cinderella was a lovely young lady who had lost her family .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'lovely'), ('JJ', 'young'), ('NN', 'lady')]
# Prenominal No: 2
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'family')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: her companions were the flowers and the birds of nature .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'companions')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: since she no longer had a family she had to go and live with her stepsisters three very well to do ladies that really had no use for Cinderella .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'use')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: rather than treat her as part of the family they sent her to work in the kitchen and sent her to clean the house .
#
# Total No: 0
# Utterance: this made her very sad .
#
# Total No: 0
# Utterance: her constant companions were always with her .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'constant'), ('NNS', 'companions')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: the flowers and the birds and the other animals of nature .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'other'), ('NNS', 'animals')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: one day a message came from the from the prince of the kingdom .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'day')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he was looking for a wife .
#
# Total No: 0
# Utterance: he came to ask the sisters to attend a ball at which time he would pick one of the ladies from the community to be his wife .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'his'), ('NN', 'wife')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: the sisters were very very excited .
#
# Total No: 0
# Utterance: Cinderella had hoped she could come .
#
# Total No: 0
# Utterance: they made it clear there was no place for her at the party .
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'place')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the sisters planned on how they would arrange to make sure that one of them became the wife of the prince .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: Cinderella helped them get dressed and helped them get ready to go and watched them take off for this grand party as she sat at her house alone and lonely .
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'grand'), ('NN', 'party')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'house')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: her fairy godmother showed up and said why have you not gone to the party .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: <Cinderella said>  I have no way to go to the party .
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'way')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the fairy godmother waved her wand and turned a pumpkin into a chariot brought out the mice waved her wand again created horses and horsemen for the chariot and said now you have a way to get to the party .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'wand')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: <Cinderella said>  fairy godmother I have no dress to wear .
#
# Extracted Phrase: [('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'dress')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: the fairy godmother waved her wand again .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'wand')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: gave her a beautiful dress and two beautiful glass shoes .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'dress')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'two'), ('JJ', 'beautiful'), ('NN', 'glass'), ('NNS', 'shoes')]
# Prenominal No: 3
#
# Total No: 4
# File: cq2yacwf.cqp.AS
# Utterance: This is a story about Cinderella .
#
# Total No: 0
# Utterance: Cinderella was a young woman .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'woman')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: her parents had apparently died .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'parents')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she was sent to live with her aunt .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'aunt')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: this lady had three other daughters .
#
# Extracted Phrase: [('CD', 'three'), ('JJ', 'other'), ('NNS', 'daughters')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: they forced Cinderella into being a maid and a cleaning lady .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'cleaning'), ('NN', 'lady')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she had to work very hard .
#
# Total No: 0
# Utterance: she was not given very nice clothes .
#
# Extracted Phrase: [('RB', 'very'), ('JJ', 'nice'), ('NNS', 'clothes')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she did not even get a lot of food to eat .
# Prenominal Quantifier 'a lot of' found.
# Prenominal No for Quantifier: 1
#
# Total No: 1
# Utterance: the three evil stepsisters were given everything .
#
# Extracted Phrase: [('DT', 'the'), ('CD', 'three'), ('JJ', 'evil'), ('NNS', 'stepsisters')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: they had beautiful clothes .
#
# Extracted Phrase: [('JJ', 'beautiful'), ('NNS', 'clothes')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: one day an invitation came from the castle .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'day')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: the prince was having a ball .
#
# Total No: 0
# Utterance: they were all invited of course .
#
# Total No: 0
# Utterance: they said Cinderella could not go .
#
# Total No: 0
# Utterance: the evil sisters spent much time and money getting beautiful dresses .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'evil'), ('NNS', 'sisters')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'much'), ('NN', 'time'), ('CC', 'and'), ('NN', 'money')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'beautiful'), ('NNS', 'dresses')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: even their coats were made of fur to go to this beautiful ball .
#
# Extracted Phrase: [('PRP$', 'their'), ('NNS', 'coats')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'beautiful'), ('NN', 'ball')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: they went to the ball .
#
# Total No: 0
# Utterance: Cinderella was left at home to clean and sweep and take care of something .
#
# Total No: 0
# Utterance: all of a sudden her fairy godmother appeared and said Cinderella you are going to go to the ball .
# Prenominal Quantifier 'all of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'sudden'), ('PRP$', 'her'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 3
#
# Total No: 4
# Utterance: the fairy godmother dressed in a beautiful gown because Cinderella had no beautiful clothes or anything to wear .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'beautiful'), ('NN', 'gown')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'no'), ('JJ', 'beautiful'), ('NNS', 'clothes'), ('CC', 'or'), ('NN', 'anything')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: she took the mice and turned them into beautiful white prancing horses .
#
# Total No: 0
# Utterance: Cinderella was taken to the castle in this beautiful carriage .
#
# Extracted Phrase: [('DT', 'this'), ('JJ', 'beautiful'), ('NN', 'carriage')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: turned mice into these beautiful white horses .
#
# Extracted Phrase: [('DT', 'these'), ('JJ', 'beautiful'), ('JJ', 'white'), ('NNS', 'horses')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: she went all the way to the castle .
#
# Extracted Phrase: [('PDT', 'all'), ('DT', 'the'), ('NN', 'way')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: when she got into the castle they let her in .
#
# Total No: 0
# Utterance: she was able to dance with the prince .
#
# Total No: 0
# Utterance: the only thing is the fairy godmother said you must be back before the stroke of midnight .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'only'), ('NN', 'thing')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: the horses will turn into mice .
#
# Total No: 0
# Utterance: you will go back to being in your rags .
#
# Extracted Phrase: [('PRP$', 'your'), ('NNS', 'rags')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: when the bells started to ring to make it twelve o'clock she went tearing out of the castle ballroom .
#
# Extracted Phrase: [('JJ', 'twelve'), ('NN', "o'clock")]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'castle'), ('NN', 'ballroom')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: on the way she lost her one of her slippers .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'slippers')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: her slippers were made of glass .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'slippers')]
# Prenominal No: 1
#
# Total No: 1
# File: d7cowzky.cqp.AS
# Utterance: Cinderella is a fairy tale that tells the story of a young girl who is without her mother and without the love of her stepmother .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'tale')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'young'), ('NN', 'girl')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'mother')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'stepmother')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: She lives with two stepsisters who take advantage of her .
#
# Extracted Phrase: [('CD', 'two'), ('NNS', 'stepsisters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: She is not given the same clothes they have .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'same'), ('NNS', 'clothes')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: She is not given the same freedom that they have .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'same'), ('NN', 'freedom')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: She is forced to clean the house and take care of the sisters and take care of the mother .
#
# Total No: 0
# Utterance: they are all described as ugly .
#
# Total No: 0
# Utterance: it could be that they are just ugly on the inside not on the outside .
#
# Total No: 0
# Utterance: one day the whole family gets an invitation to the Prince's Ball .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'day')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'whole'), ('NN', 'family')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NNP', 'Prince'), ('POS', "'s"), ('NN', 'Ball')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: the sisters are all very excited including Cinderella .
#
# Total No: 0
# Utterance: they make it clear to her that she is not included .
#
# Total No: 0
# Utterance: she has to stay home .
#
# Total No: 0
# Utterance: her task is to help them get dressed and help them with their hair and get them all beautiful .
#
# Extracted Phrase: [('PRP$', 'her'), ('NN', 'task')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'their'), ('NN', 'hair')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: Get the stepmom and the sisters ready to go to the event .
#
# Total No: 0
# Utterance: off they go leaving poor Cinderella at home alone where she feels very sad .
#
# Extracted Phrase: [('JJ', 'poor'), ('NNP', 'Cinderella')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: along comes the answer to her dreams and prayers a fairy godmother who offers to help her find a way to participate .
#
# Extracted Phrase: [('PRP$', 'her'), ('NNS', 'dreams'), ('CC', 'and'), ('NNS', 'prayers')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'fairy'), ('NN', 'godmother')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: she gives her beautiful clothes and beautiful hair .
#
# Extracted Phrase: [('PRP$', 'her'), ('JJ', 'beautiful'), ('NNS', 'clothes')]
# Prenominal No: 2
#
# Extracted Phrase: [('JJ', 'beautiful'), ('NN', 'hair')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: she also provides her with the same kinds of horses and  carriage so that she can attend the ball .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'same'), ('NNS', 'kinds')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: this is all done through magic using various animals who live in the area and a pumpkin .
#
# Extracted Phrase: [('JJ', 'various'), ('NNS', 'animals')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: All these things are turned into what she needs .
#
# Extracted Phrase: [('PDT', 'All'), ('DT', 'these'), ('NNS', 'things')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: she attends the ball .
#
# Total No: 0
# Utterance: she gets there and enjoys the ball very much by dancing with the Prince .
#
# Total No: 0
# ...
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'rowing'), ('NN', 'club')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: obviously it is not like a actual collegiate rowing club just recreational .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'actual'), ('JJ', 'collegiate'), ('NN', 'rowing'), ('NN', 'club')]
# Prenominal No: 3
#
# Total No: 3
# Utterance: essentially we have a mix between land practice and water practice .
#
# Extracted Phrase: [('NN', 'land'), ('NN', 'practice'), ('CC', 'and'), ('NN', 'water'), ('NN', 'practice')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: it is full of undergrads and grads .
#
# Total No: 0
# Utterance: last year it was mostly grad students .
#
# Extracted Phrase: [('JJ', 'last'), ('NN', 'year')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'grad'), ('NNS', 'students')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: I think probably because of Coronavirus .
#
# Total No: 0
# Utterance: there was not that many people there .
#
# Extracted Phrase: [('JJ', 'many'), ('NNS', 'people')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: now we have a team of maybe initially started off at thirty five at the first meeting .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'first'), ('NN', 'meeting')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: it definitely has gone down .
#
# Total No: 0
# Utterance: people have not showed up .
#
# Total No: 0
# Utterance: the times are kind of hard to schedule .
#
# Total No: 0
# Utterance: it was just when I was my freshman year first semester .
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'freshman'), ('NN', 'year'), ('JJ', 'first'), ('NN', 'semester')]
# Prenominal No: 4
#
# Total No: 4
# Utterance: I was kind of bored .
#
# Total No: 0
# Utterance: I needed an activity to stay in shape throughout school .
#
# Total No: 0
# Utterance: decided that showing up for Rowing Club which in that first semester last year fall problem was it started at four thirty AM .
#
# Extracted Phrase: [('NNP', 'Rowing'), ('NNP', 'Club')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'that'), ('JJ', 'first'), ('NN', 'semester')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'last'), ('NN', 'year')]
# Prenominal No: 1
#
# Extracted Phrase: [('NN', 'fall'), ('NN', 'problem')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: it was pretty much hell .
#
# Extracted Phrase: [('RB', 'pretty'), ('JJ', 'much'), ('NN', 'hell')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: torture .
#
# Total No: 0
# Utterance: I only got like five hours of sleep a day .
#
# Extracted Phrase: [('CD', 'five'), ('NNS', 'hours')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: sleep deprived completely for an entire semester .
#
# Extracted Phrase: [('DT', 'an'), ('JJ', 'entire'), ('NN', 'semester')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: I am not sure how I did not tell myself that this was a problem or not .
#
# Total No: 0
# Utterance: I woke up four AM .
#
# Extracted Phrase: [('CD', 'four'), ('NN', 'AM')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: had to go to Tudor or at the arch at four thirty so I could get carpooled to where we actually rode on water or to Tudor to do the ERGs .
#
# Total No: 0
# Utterance: I started off my morning everybody else in that club for no reason just absolutely putting our bodies through things that a student should not .
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'morning'), ('NN', 'everybody')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'no'), ('NN', 'reason')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'our'), ('NNS', 'bodies')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: I do not only have bad memories of rowing .
#
# Extracted Phrase: [('JJ', 'bad'), ('NNS', 'memories')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: it was not bad .
#
# Total No: 0
# Utterance: I mean it was not a good experience .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'good'), ('NN', 'experience')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: I kind of had a very unique experience .
#
# Extracted Phrase: [('DT', 'a'), ('RB', 'very'), ('JJ', 'unique'), ('NN', 'experience')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: a very much more extreme experience than most people .
#
# Extracted Phrase: [('DT', 'a'), ('RB', 'very'), ('RB', 'much'), ('JJR', 'more'), ('JJ', 'extreme'), ('NN', 'experience')]
# Prenominal No: 4
#
# Extracted Phrase: [('JJS', 'most'), ('NNS', 'people')]
# Prenominal No: 1
#
# Total No: 5
# Utterance: I am not sure if that relativity matters so much .
#
# Extracted Phrase: [('DT', 'that'), ('NN', 'relativity'), ('NNS', 'matters')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: kind of burned out after .
#
# Total No: 0
# File: YA80.cqp.AS
# Utterance: one of my hobbies that I recently had was founding my startup flow .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'my'), ('NNS', 'hobbies')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'startup'), ('NN', 'flow')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: I started it during Covid in my junior year of high school with two other co-founders .
#
# Extracted Phrase: [('PRP$', 'my'), ('JJ', 'junior'), ('NN', 'year')]
# Prenominal No: 2
#
# Extracted Phrase: [('JJ', 'high'), ('NN', 'school')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'two'), ('JJ', 'other'), ('NNS', 'co-founders')]
# Prenominal No: 2
#
# Total No: 5
# Utterance: in the beginning they did an incubator .
#
# Total No: 0
# Utterance: afterwards I joined them on the project where we designed reusable tampon applicators .
#
# Extracted Phrase: [('JJ', 'reusable'), ('NN', 'tampon'), ('NNS', 'applicators')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: we filed a patent .
#
# Total No: 0
# Utterance: eventually we also got an attorney to register our product so that we could file the patent .
#
# Extracted Phrase: [('PRP$', 'our'), ('NN', 'product')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: we registered our company as a limited liability company .
#
# Extracted Phrase: [('PRP$', 'our'), ('NN', 'company')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'limited'), ('NN', 'liability'), ('NN', 'company')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: afterwards I was the chief marketing officer .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'chief'), ('NN', 'marketing'), ('NN', 'officer')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: I was in charge of marketing .
#
# Total No: 0
# Utterance: although we had some funds we needed more funds .
#
# Extracted Phrase: [('DT', 'some'), ('NNS', 'funds')]
# Prenominal No: 1
#
# Extracted Phrase: [('RBR', 'more'), ('NNS', 'funds')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: we decided to launch a Kickstarter .
#
# Total No: 0
# Utterance: we filmed a Kickstarter video at one of my co-founder's houses .
# Prenominal Quantifier 'one of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('DT', 'a'), ('NNP', 'Kickstarter'), ('NN', 'video')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'co-founder'), ('POS', "'s"), ('NNS', 'houses')]
# Prenominal No: 2
#
# Total No: 4
# Utterance: we also went to Hawaii to do a photo shoot for our product .
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'photo'), ('NN', 'shoot')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'our'), ('NN', 'product')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: I helped design the product box .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'product'), ('NN', 'box')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: in which we also did a shoot for .
#
# Total No: 0
# Utterance: we had a little pouch with organic tampons in our reusable tampon applicator .
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'little'), ('NN', 'pouch')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'organic'), ('NNS', 'tampons')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'our'), ('JJ', 'reusable'), ('NN', 'tampon'), ('NN', 'applicator')]
# Prenominal No: 3
#
# Total No: 5
# Utterance: after we designed our Kickstarter video we hired some people to render videos for certain parts of the video .
#
# Extracted Phrase: [('PRP$', 'our'), ('NNP', 'Kickstarter'), ('NN', 'video')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'some'), ('NNS', 'people')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'certain'), ('NNS', 'parts')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: overall the story that we were trying to convey was that reusable tampon applicators could reduce the amount of plastic waste and microplastics that get into the ocean .
#
# Extracted Phrase: [('JJ', 'reusable'), ('NN', 'tampon'), ('NNS', 'applicators')]
# Prenominal No: 2
#
# Extracted Phrase: [('NN', 'plastic'), ('NN', 'waste')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: in addition it is more inclusive .
#
# Total No: 0
# Utterance: it promotes body positivity .
#
# Extracted Phrase: [('NN', 'body'), ('NN', 'positivity')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: we launched our Kickstarter .
#
# Extracted Phrase: [('PRP$', 'our'), ('NNP', 'Kickstarter')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: we had different scales in which you could donate money to get stickers or one product or two products for example .
#
# Extracted Phrase: [('JJ', 'different'), ('NNS', 'scales')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'product')]
# Prenominal No: 1
#
# Extracted Phrase: [('CD', 'two'), ('NNS', 'products')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: after that we had an intern from Australia .
#
# Total No: 0
# Utterance: she worked on our project .
#
# Extracted Phrase: [('PRP$', 'our'), ('NN', 'project')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: we built our social media page on Instagram Facebook and LinkedIn .
#
# Extracted Phrase: [('PRP$', 'our'), ('JJ', 'social'), ('NNS', 'media'), ('NN', 'page')]
# Prenominal No: 3
#
# Extracted Phrase: [('NNP', 'Instagram'), ('NNP', 'Facebook'), ('CC', 'and'), ('NNP', 'LinkedIn')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: I also worked on making ads basically through the Facebook business page side .
#
# Extracted Phrase: [('DT', 'the'), ('NNP', 'Facebook'), ('NN', 'business'), ('NN', 'page'), ('NN', 'side')]
# Prenominal No: 3
#
# Total No: 3
# Utterance: I kind of learned how to increase engagement and cost per click .
#
# Total No: 0
# Utterance: the other people focused on perfecting our product .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'other'), ('NNS', 'people')]
# Prenominal No: 1
#
# Extracted Phrase: [('PRP$', 'our'), ('NN', 'product')]
# Prenominal No: 1
#
# Total No: 2
# File: YA9.cqp.AS
# Utterance: one thing I really like to do is write song lyrics .
#
# Extracted Phrase: [('CD', 'one'), ('NN', 'thing')]
# Prenominal No: 1
#
# Extracted Phrase: [('NN', 'song'), ('NNS', 'lyrics')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: it started back in the eighth grade .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'eighth'), ('NN', 'grade')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: before I had a journal where I was writing a bunch of poetry and diary entries as a middle schooler .
# Prenominal Quantifier 'a bunch of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('NN', 'diary'), ('NNS', 'entries')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'a'), ('JJ', 'middle'), ('NN', 'schooler')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: I got a crush on this guy in eighth grade .
#
# Extracted Phrase: [('JJ', 'eighth'), ('NN', 'grade')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he loved song lyrics .
#
# Extracted Phrase: [('NN', 'song'), ('NNS', 'lyrics')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: he liked writing his own song lyrics .
#
# Extracted Phrase: [('PRP$', 'his'), ('JJ', 'own'), ('NN', 'song'), ('NNS', 'lyrics')]
# Prenominal No: 3
#
# Total No: 3
# Utterance: I was like why do not I do the same thing .
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'same'), ('NN', 'thing')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: because of my crush I started getting into song lyric writing .
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'crush')]
# Prenominal No: 1
#
# Extracted Phrase: [('NN', 'song'), ('NN', 'lyric'), ('NN', 'writing')]
# Prenominal No: 2
#
# Total No: 3
# Utterance: I wrote my first song in eighth grade .
#
# Extracted Phrase: [('PRP$', 'my'), ('JJ', 'first'), ('NN', 'song')]
# Prenominal No: 2
#
# Extracted Phrase: [('JJ', 'eighth'), ('NN', 'grade')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: it was a very slow song .
#
# Extracted Phrase: [('DT', 'a'), ('RB', 'very'), ('JJ', 'slow'), ('NN', 'song')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: I added guitar to it because at the time I was doing guitar lessons .
#
# Extracted Phrase: [('NN', 'guitar'), ('NNS', 'lessons')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: I got help from my guitar teacher to even create the whole song together and record it and even put on SoundCloud .
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'guitar'), ('NN', 'teacher')]
# Prenominal No: 2
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'whole'), ('NN', 'song')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: after that I just started writing more .
#
# Total No: 0
# Utterance: I went to a writing camp actually the summer after freshman year of high school where I got to collaborate with a bunch of other songwriters .
# Prenominal Quantifier 'a bunch of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('DT', 'a'), ('NN', 'writing'), ('NN', 'camp')]
# Prenominal No: 1
#
# Extracted Phrase: [('RB', 'actually'), ('DT', 'the'), ('NN', 'summer')]
# Prenominal No: 1
#
# Extracted Phrase: [('NN', 'freshman'), ('NN', 'year')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'high'), ('NN', 'school')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'other'), ('NNS', 'songwriters')]
# Prenominal No: 1
#
# Total No: 6
# Utterance: also other writers from other sectors such as nonfiction writing fiction writing poetry .
#
# Extracted Phrase: [('JJ', 'other'), ('NNS', 'writers')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'other'), ('NNS', 'sectors')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'nonfiction'), ('NN', 'writing'), ('NN', 'fiction'), ('NN', 'writing'), ('NN', 'poetry')]
# Prenominal No: 4
#
# Total No: 6
# Utterance: I got a lot of ideas from that and really grew my writing .
# Prenominal Quantifier 'a lot of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'writing')]
# Prenominal No: 1
#
# Total No: 2
# Utterance: as I wrote more lyrics I went through several different journals throughout high school .
#
# Extracted Phrase: [('JJR', 'more'), ('NNS', 'lyrics')]
# Prenominal No: 1
#
# Extracted Phrase: [('JJ', 'several'), ('JJ', 'different'), ('NNS', 'journals')]
# Prenominal No: 2
#
# Extracted Phrase: [('JJ', 'high'), ('NN', 'school')]
# Prenominal No: 1
#
# Total No: 4
# Utterance: I probably on my eighth one right now .
#
# Extracted Phrase: [('PRP$', 'my'), ('JJ', 'eighth'), ('NN', 'one')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: by the summer after junior year I went to the writing camp again except the longer term of it .
#
# Extracted Phrase: [('JJ', 'junior'), ('NN', 'year')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'writing'), ('NN', 'camp')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJR', 'longer'), ('NN', 'term')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: this time I was going there for four weeks .
#
# Extracted Phrase: [('CD', 'four'), ('NNS', 'weeks')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: I really got to get into my craft .
#
# Extracted Phrase: [('PRP$', 'my'), ('NN', 'craft')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: by that time I was able to progress on seven different songs .
#
# Extracted Phrase: [('CD', 'seven'), ('JJ', 'different'), ('NNS', 'songs')]
# Prenominal No: 2
#
# Total No: 2
# Utterance: I had the goal of coming out with an EP album on SoundCloud like any of the other rappers out there .
# Prenominal Quantifier 'any of' found.
# Prenominal No for Quantifier: 1
#
# Extracted Phrase: [('DT', 'an'), ('NN', 'EP'), ('NN', 'album')]
# Prenominal No: 1
#
# Extracted Phrase: [('DT', 'the'), ('JJ', 'other'), ('NNS', 'rappers')]
# Prenominal No: 1
#
# Total No: 3
# Utterance: I finished the writing camp .
#
# Extracted Phrase: [('DT', 'the'), ('NN', 'writing'), ('NN', 'camp')]
# Prenominal No: 1
#
# Total No: 1
# Utterance: I kept working on the lyrics that I had .
#
# Total No: 0
# Utterance: I worked on it throughout the beginning of my senior year as well .
#
# Extracted Phrase: [('PRP$', 'my'), ('JJ', 'senior'), ('NN', 'year')]
# Prenominal No: 2
#
# Total No: 2
# All files processed successfully.

# %% [markdown]
# # Debugging One Sentence at a time

# %%
# Define the function to extract leaves from the tree (same as before)
def extract_leaves(tree):
    leaves = []  # List to collect leaves

    def traverse(node):
        if isinstance(node, tuple) and isinstance(node[1], list):
            if all(isinstance(item, tuple) for item in node[1]):
                for item in node[1]:
                    traverse(item)
            else:
                leaves.extend([(node[0], subitem) for subitem in node[1]])
        elif isinstance(node, list):
            for subnode in node:
                traverse(subnode)

    traverse(tree)
    return leaves

# Define the function to scan modifiers (same as before)
def scan_modifiers(leaves, special_phrases):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC", "TO", "IN", "POS", "CC", "RP", "PDT"]
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals  # Include 'been' in the exclusions
    CC_pos = ["CC"]

    # Add the specific prenominal quantifier phrases to exclude
    Prenominal_Quantifier_Words = ['many', 'all', 'most', 'some', 'few', 'several', 'number', 'bit', "lot","bunch", "any", "one"]

    # Count modifiers that are not in the excluded lists
    modifier_count = 0

    for ii, (pos, word) in enumerate(leaves[-2::-1]):  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            # Check for prenominal quantifier phrases
            if word in Prenominal_Quantifier_Words and ii + 1 < len(leaves) and leaves[-ii-2][1] == 'of':
                continue  # Skip the word if it is part of a prenominal quantifier phrase
            
            # Check if the current leaf contains a special phrase
            leaf_phrase = ' '.join(leaf[1] for leaf in leaves[-ii - 2:])
            if any(special_phrase in leaf_phrase for special_phrase in special_phrases):
                continue  # Skip if it matches any special phrase
            
            # Increment the modifier count
            modifier_count += 1

        if pos in CC_pos:
            if ii + 1 < len(leaves) and leaves[-ii-1][0] in All_Nouns:
                modifier_count -= 1
                continue
            elif ii + 2 < len(leaves) and leaves[-ii-2][0] == "DT":
                break

    return modifier_count

# Define lists of POS tags and specific words to be considered or excluded (same as before)
All_Nouns = ["NN", "NNS", "NNP", "NNPS"]
All_Adjectives = ["JJ", "JJR", "JJS", "PRP$"]
All_Adverbs = ["RB", "RBR", "RBS"]
Verbs_that_can_be_prenominal = ["VBN"]
Determiners_to_be_excluded_as_prenominals = ["a", "A", "an", "An", "the", "The", "that", "That", "these", "These", "those", "Those", "this", "This", "either", "Either", "around", "Around"]
Words_to_be_excluded_as_prenominals = ["been","around", "almost", "never","behind","above","whose","which"]
Prenominal_Quantifier_Phrases = ['a lot of', 'many of', 'all of', 'most of', 'some of', 'a few of', 'several of', 'a number of', 'a bit of', 'a bunch of', "any of", "one of"]

# Directory mapping (same as before)
directory_mapping = {
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\buggy sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\buggy sentences"
}

# Ensure destination directories exist (same as before)
for dest in directory_mapping.values():
    os.makedirs(dest, exist_ok=True)

# Define the function to process Excel files
def process_excel_file(src_file_path, dest_file_path):
    # Load the workbook and worksheet
    wb = load_workbook(src_file_path)
    ws = wb.active

    # Find the last row with data in column B
    last_row = ws.max_row
    last_row_formulas = {}  # Dictionary to store formulas in the last row

    for col in range(2, ws.max_column + 1):
        col_letter = get_column_letter(col)
        # Check if the header is "Comments"
        if ws[f'{col_letter}1'].value == "Comments":
            continue
        # Calculate the sum of values in the column (excluding the header)
        column_sum = 0
        for row in range(2, last_row + 1):
            cell_value = ws[f'{col_letter}{row}'].value
            if isinstance(cell_value, (int, float)):
                column_sum += cell_value
            elif cell_value == 'N/A':
                continue
        # Check if the last row contains a string that starts with "=SUM"
        last_row_value = ws[f'{col_letter}{last_row}'].value
        if isinstance(last_row_value, str) and last_row_value.startswith("=SUM"):
            last_row_formulas[col_letter] = last_row_value
        elif not isinstance(last_row_value, str) or not last_row_value.startswith("=SUM"):
            next_row = last_row + 1
            ws[f'{col_letter}{next_row}'] = column_sum
    
    # Save the file to the specified destination path
    wb.save(dest_file_path)
    
    # Load the processed data into pandas for further manipulation
    data = pd.read_excel(dest_file_path)

    # Data manipulation logic (same as before, ensuring that formula rows are preserved)
    data.insert(1, 'Prenominal Modifiers', '')

    for index, row in data.iterrows():
        utterance = row['UTTERANCES']
        if pd.isna(utterance) or utterance.strip() == '':
            continue  # Skip this iteration if the cell is blank or empty
        
        utterance = utterance.replace("[+ 0subj]", "").replace("[+ gram]", "").replace("0det", "")
        print(f"Utterance: {utterance}")

        sentence_class = sentence_tree(utterance)
        special_phrase_count = sentence_class.handle_special_phrases(Prenominal_Quantifier_Phrases, utterance)
        sentence_class.prune_to_np_branches(sentence_class.parse_tuples)
        nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])
        nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)
        total_modifiers = 0
        for tree in nps_factored_for_complicated_NP_embedding[0]:
            leaves = extract_leaves(tree)
            modifier_count = scan_modifiers(leaves, Prenominal_Quantifier_Phrases)
            total_modifiers += modifier_count
            if modifier_count > 0:  # Change to >0 when debugging
                print()
                print("Extracted Phrase:", leaves)
                print(f"Prenominal No: {modifier_count}")
        total_modifiers += special_phrase_count
        print()
        print(f"Total No: {total_modifiers}")
        data.at[index, 'Prenominal Modifiers'] = total_modifiers

    data['Prenominal Modifiers'] = pd.to_numeric(data['Prenominal Modifiers'], errors='coerce')
    data['Prenominal Modifiers'].fillna(0, inplace=True)

    # Save the DataFrame back to Excel
    data.to_excel(dest_file_path, index=False)

    # Reload the workbook to reapply formulas
    wb = load_workbook(dest_file_path)
    ws = wb.active
    last_row = len(data) + 1
    ws[f'B{last_row}'] = f"=SUM(B2:B{last_row-1})"
    next_row = last_row + 1
    ws[f'A{next_row}'] = "Prenominal Modifiers/#Nouns"
    ws[f'B{next_row}'] = f"=B{last_row}/G{last_row}"
    wb.save(dest_file_path)

# %%
# Loop through each directory and process each file
for src_directory, dest_directory in directory_mapping.items():
    excel_files = glob.glob(os.path.join(src_directory, '*.xlsx'))
    for file_path in excel_files:
        file_name = os.path.basename(file_path)
        base_name = os.path.splitext(file_name)[0]
        dest_file_path = os.path.join(dest_directory, file_name)
        print(f"File: {base_name}")
        process_excel_file(file_path, dest_file_path)

print("All files processed successfully.")

# %% [markdown]
# # SENTENCE STEP-BY-STEP DEBUGGING

# %%
#sentence = "the brown fox on the swing and the bad granddaughter on the playground are bad"
#sentence = "The brown and red fox is quick and he is jumping over the lazy dog."
#sentence = "The antique clock's gentle ticking filled the quiet room."
#sentence = "The gentle ticking of the antique clock filled the quiet room."
#sentence = "The bad man and the soon to be born daughter are weird
#sentence = "Her stepmother got an invitation to the red prince's strange Ball ."
#sentence = "Cinderella basically did all the chores at home all day and all night ."
#sentence = "one day the family received an invitation to the ball ."
#sentence = " the Fairy Godmother gave Cinderella a dress to wear as well as a carriage ride and two glass slippers ."
#sentence = "the following day the prince goes around town going to everybody trying to see whose feet the glass slipper fits ."
sentence = "Cinderella is about a young girl who has some stepsisters ."
sentence_class = sentence_tree(sentence)

# %%
sentence_class.prune_to_np_branches(sentence_class.parse_tuples)

for tree in sentence_class.prune_tree[0]:
    print(tree)
    print()

# %%
nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])

for tree in nps_without_POS:
    print()
    print(tree)

# %%
nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)

for tree in nps_factored_for_complicated_NP_embedding[0]:
    print(tree)
    print()

# %%
#SENTENCE TUPLE TREE
for tree in sentence_class.indexed_tuples:
    print(tree)
    print()

# %%
sentence_class.tree_to_string_no_labels(sentence_class.indexed_tuples, True)

# %% [markdown]
# # Graveyard

# %%
sentence_tupletree = [('ROOT', [('S', [('NP', [('NP', [('NP', [('DT', ['the']), ('JJ', ['brown']), ('NN', ['fox'])]), 
                                                      ('PP', [('IN', ['on']), ('NP', [('DT', ['the']), ('NN', ['swing'])])])]),
                                       ('CC', ['and']),
                                       ('NP', [('NP', [('DT', ['the']), ('JJ', ['bad']), ('NN', ['granddaughter'])]), 
                                               ('PP', [('IN', ['on']), ('NP', [('DT', ['the']), ('NN', ['playground'])])])
                                              ])]), 
                                      ('VP', [('VBP', ['are']), ('ADJP', [('JJ', ['bad'])])])
                                     ])]),
                      
                      ('ROOT', [('S', [('S', [('NP', [('DT', ['The']), ('ADJP', [('JJ', ['brown']), ('CC', ['and']), 
                                                                                 ('JJ', ['red'])]), ('NN', ['fox'])]),
                                              ('VP', [('VBZ', ['is']), ('ADJP', [('JJ', ['quick'])])])]), ('CC', ['and']),
                                       ('S', [('NP', [('PRP', ['he'])]),
                                              ('VP', [('VBZ', ['is']), ('VP', [('VBG', ['jumping']), ('PP', [('IN', ['over']), 
                                                                               ('NP', [('DT', ['the']), ('JJ', ['lazy']), ('NN', ['dog'])
                                                     ])])])])]),
                                       ('.', ['.'])])]),
                      
                      ('ROOT', [('S', [('NP', [('NP', [('DT', ['The']), ('JJ', ['antique']), ('NN', ['clock']), ('POS', ["'s"])]),
                                               ('JJ', ['gentle']), ('NN', ['ticking'])]), ('VP', [('VBD', ['filled']), 
                                                                                                  ('NP', [('DT', ['the']), 
                                                                                                          ('JJ', ['quiet']), 
                                                                                                          ('NN', ['room'])])]),
                                       ('.', ['.'])])]),
                      
                      ('ROOT', [('S', [('NP', [('NP', [('DT', ['The']), ('JJ', ['gentle']), ('NN', ['ticking'])]), 
                                               ('PP', [('IN', ['of']), ('NP', [('DT', ['the']), ('JJ', ['antique']), ('NN', ['clock'])])])]),
                                       ('VP', [('VBD', ['filled']), ('NP', [('DT', ['the']), ('JJ', ['quiet']), ('NN', ['room'])])]),
                                ('.', ['.'])])]),
                      
                      ('ROOT', [('S', [('NP', [('NP', [('DT', ['the']), ('JJ', ['bad']), ('NN', ['man'])]),
                                               ('CC', ['and']), ('NP', [('DT', ['the']),
                                               ('NML', [('S', [('ADVP', [('RB', ['soon'])]), 
                                                               ('VP', [('TO', ['to']), ('VP', [('VB', ['be']), 
                                                                       ('VP', [('VBN', ['born'])])])])])]),
                                               ('NN', ['daughter'])])]),
                                       ('VP', [('VBP', ['are']), ('ADJP', [('JJ', ['weird'])])])])]),
                      
                      ('ROOT', [('S', [('NP', [('PRP$', ['Her']), ('NN', ['stepmother'])]), 
                                       ('VP', [('VBD', ['got']), ('NP', [('DT', ['an']), ('NN', ['invitation'])]),
                                               ('PP',  [('IN', ['to']), ('NP', [('NP', [('DT', ['the']), ('JJ', ['red']),
                                                        ('NN', ['prince']), ('POS', ["'s"])]), ('JJ', ['strange']),
                                                        ('NN', ['Ball'])])])]),
                                       ('.', ['.'])])]),
                     ]

# %%
class sentence_tree:
    """
    The sentence_tree class is a collection of functions and variables to perform operations and collect 
    statistics on a sentence respectively
    """

    def __init__(self, sentence):
        
        """
        This function initializes my class
        
        INPUT:
            sentence - sentence string to process
        """
        self.sentence = sentence
        self.tree = next(parser.raw_parse(self.sentence))
        self.parse_tuples = self.tree_to_tuples(self.tree)
        self.position_in_sentence = [0] #variable to keep track of position in sentence through recursions
        self.indexed_tuples =  self.create_indexed_tuples(self.parse_tuples,  self.position_in_sentence)
        self.prune_tree = [[]]#This stores all the trees with NPs in the sentence
        self.Noun_List = ["NN","NNS","NNP","NNPS"] #this stores all parts of speech that can be treated as a noun phrase
        self.Noun_Phrases = ['NP','NP-TMP','WHNP'] #list of all noun phrases
    

    def tree_to_tuples(self, tree):
        """
            Create nltk tree from sentence
            
            INPUT:
                tree - tuple tree
            OUTPT:
                nltk.Tree object created from tree
        """
        if isinstance(tree, nltk.Tree):
            return (tree.label(), [self.tree_to_tuples(t) for t in tree])
        else:
            return tree

    def flatten_list(self, input_list):
        flattened = []
        for item in input_list:
            if isinstance(item, list):
                flattened.extend(self.flatten_list(item))  # Recursively flatten the list
            else:
                flattened.append(item)  # Append the string or non-list item directly
        return flattened

    def is_sublist(self, sub_list, main_list, keep = False):
        len_sub = len(sub_list)
        if not keep:
            if len_sub == len(main_list):
                return False
        for i in range(len(main_list) - len_sub + 1):
            if main_list[i:i + len_sub] == sub_list:
                return True
        return False
    
    def create_indexed_tuples(self, tree, position):
        """
        Create a tuple tree that replaces the word in the leaves with a list [word, position in sentence]
        
        INPUT:
            tree - tuple tree
            positio - list to hold value of the position in string through recursions
        """
        if isinstance(tree, tuple):
            label, children = tree
            new_children = []
            for child in children:
                new_children.append(self.create_indexed_tuples(child, position))
            return (label, new_children)
        else:
            position[0] += 1
            return ({'word' : tree, 'position' : position[0]})
    
    def prune_to_np_branches(self, tree):
        """
        Function wrapper to call prune_general specifically to collect NPs
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            assignment to self.prune_tree of the list of NP strings
        """
        
        self.prune_tree = [[]]
        self.prune_general(tree, self.prune_tree, PoS = ['NP','NP-TMP','WHNP'])
        
    def prune_general(self, tree, tree2, PoS = ['NP','NP-TMP','WHNP']):
        """
        General case function for collecting the trees assosciated with a part of speech, PoS, for the tuple tree
        in tree and collecting them in tree 2
        INPUT:
            tree  - a tuple tree
            tree2 - a list of a list of tuple trees containing part of speech being searched for. 
                    It is a list so that the list of tuples can be appended in every recursive call.  
            PoS   - the part of speech that is being collected in tree2.  The default is Noun Phrase (NP)
        OUTPUT:
            modifies tree2 to store on the parts of speech specified by PoS for the sentence (in the form of a list of tuple trees) in tree
            The return value is None this signifies the last tuple (string, list) has been reached
        
        """
        if isinstance(tree, tuple): #Check that tree is a tuple tree and not a list
            label, children = tree #extracts the string and list from the tuple 
            """
            print("label:",label)
            print("children:",children)
            print()
            """
            if label in PoS:
                # If it's a node matching the part of speech save it to tree2
                tree2[0].append(tree) 
            if isinstance(children, list):#check if children is a path (list) and not a string
                # Recursively check children; keep those leading to an NP
                """
                for child in children:
                    print("child: ", child)
                    print()
                """
                for child in children:
                    np_children = self.prune_general(child, tree2, PoS = self.Noun_Phrases) #process each path in the tree
        return None
    
    def Does_Tree_Have_Target(self, tree, target = ['NP','NP-TMP','WHNP']): 
        """
        Check if a tree has the target part of speech (Either Posessive or NP)
        INPUT:
        tree  - tuple tree being scanned
        target - part of speech being targeted, default NP
        """
        recursion_for_target = False
        if isinstance(tree, tuple): #check if tree is in (string label, path list) form
            label, children = tree
            if label in target: #doesnt have to be NP, can be varialbe that can be assigned either as NP or POS
                return True
            else:
                for ii, child in enumerate(children):
                    if child[0] == target:
                        return True
                    else:
                        if self.Does_Tree_Have_Target(child, target):
                            recursion_for_target = True
        if recursion_for_target:
            return True
        else:
            return False
    
    """
    def Trees_without_NPs(self, tree):
        self.prune_tree = []
        Trees_without_NPs_List = []
        self.prune_to_np_branches(tree)
        for p_tree in self.prune_tree:
            if not self.Does_Tree_Have_Target(("Root",p_tree[1])):
                Trees_without_NPs_List.append(p_tree)
        return Trees_without_NPs_List
    """
    
    
    
    def tree_to_string_no_labels(self, tree, is_indexed = False):
        """
        Convert a tuple tree to the sentence string it represents
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            this function is recursive so it returns a tuple tree if it is still processing a tree,
            otherwise it returns a string with all of the substrings appended together
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple): #and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return " ".join([self.tree_to_string_no_labels(branch, is_indexed) for branch in branches]).strip()
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return " ".join([self.tree_to_string_no_labels(leaf, is_indexed) for leaf in tree]).strip()
        # Base case: the tree is a leaf (a word)
        else:
            if is_indexed:
                return tree['word']
            else:
                return tree

    ''' DEPRICATED   
    def tree_to_string_no_labels_part_2(self, tree_list):
        """
        Convert each tree in the list to a string, excluding all grammatical labels
        
        INPUT:
            tree_list - list of tuple strings to process
        """
        tree_strings_no_labels = [self.tree_to_string_no_labels(tree) for tree in tree_list]
        return tree_strings_no_labels
    '''
    '''
    def tree_to_string_no_labels(self, tree):
        """
        Covert a tuple tree to the sentence string it represents
        
        INPUT:
            tree - tuple tree
        OUTPUT:
            this function is recursive so it returns a tuple tree if it is still processing a tree,
            otherwise it returns a string with all of the substrings appended together
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple) and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return " ".join([self.tree_to_string_no_labels(branch) for branch in branches]).strip()
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return " ".join([self.tree_to_string_no_labels(leaf) for leaf in tree]).strip()
        # Base case: the tree is a leaf (a word)
        else:
            return tree
    '''
    def tree_to_list_of_strings(self, tree, is_indexed = False):
        """
        Convert a tree of a list of strings without grammatical labels
        
        INPUT:
            tree - tuple tree
            is_index - is the tuple tree standard (False) or have indexing (True)
        OUTPUT:
            list of the strings in the tuple tree
        """
        # Check if the tree is a tuple with a tag and a list of subtrees or leaves
        if isinstance(tree, tuple) and len(tree) == 2:
            _, branches = tree
            # Recursively process branches to get strings without labels
            return self.flatten_list([self.tree_to_list_of_strings(branch, is_indexed) for branch in branches])
        # If the tree is a list, it's a list of subtrees or leaves
        elif isinstance(tree, list):
            return [self.tree_to_list_of_stings(leaf, is_indexed) for leaf in tree]
        # Base case: the tree is a leaf (a word)
        else:
            if is_indexed:
                return tree['word']
            else:
                return tree

    
    def list_of_trees_to_list_of_strings(self, tree_list, is_indexed = False):
        """
        Convert each tree in a list to a string list, excluding all grammatical labels
        
        INPUT:
            list of trees
            
        OUPUT:
            list of string lists
        """
        tree_strings_no_labels = [self.tree_to_list_of_strings(tree, is_indexed) for tree in tree_list]
        return tree_strings_no_labels

    '''DEPRICATE
    def duplicate_NP_removal(self, tree, keep_substring = False):
        """
        remove strings that overlap with other strings
        
        INPUT:
            tree - tuple tree to be processed 
            keep_substring - Boolean switch to determine if substrings are kept or the containing string
                             default is False
        OUTPUT:
            list of NP tupple tree strings with overlapping strings removed
        """
        strings_with_NPs = self.tree_to_string_no_labels_part_2(tree)
        strings_with_NPs_True_Or_False_Array = [True] * len(strings_with_NPs)

        for idx,s in enumerate(strings_with_NPs):
            for idy,t in enumerate(strings_with_NPs[idx+1:]):
                if strings_with_NPs[idx] in strings_with_NPs[idy+1+idx]:
                    if keep_substring:
                        strings_with_NPs_True_Or_False_Array[idy+1+idx] = False
                    else:
                        strings_with_NPs_True_Or_False_Array[idx] = False
                elif strings_with_NPs[idy+1+idx] in strings_with_NPs[idx]:
                    if keep_substring:
                        strings_with_NPs_True_Or_False_Array[idx] = False
                    else:
                        strings_with_NPs_True_Or_False_Array[idy+1+idx] = False
        nps_without_duplicates = []
        for ii,noun_phrase in enumerate(tree):
            if strings_with_NPs_True_Or_False_Array[ii]:
                nps_without_duplicates.append(noun_phrase)
        return nps_without_duplicates
    '''
    
    def check_and_remove_PoS(self, tree, PoS = 'POS'):
        """
        Remove trees with the chosen label and return modified tree
        
        INPUT:
           tree - tuple tree to check for PoS
           PoS - part of speech being removed from tuple tree
        OUTPUT:
            returns tuple tree with all subtree with PoS label removed
        """
        if isinstance(tree, tuple):
            # If the tuple contains 'POS', return None to signify removal
            if tree[0] == 'POS':
                return None
            else:
                # Otherwise, recursively process and rebuild the tuple without 'POS'
                return (tree[0], [self.check_and_remove_PoS(sub_t, PoS) for sub_t in tree[1] if self.check_and_remove_PoS(sub_t, PoS) is not None])
        elif isinstance(tree, list):
            # For lists, filter through and only keep items that should not be removed
            return [self.check_and_remove_PoS(sub_t, PoS) for sub_t in tree if self.check_and_remove_PoS(sub_t, PoS) is not None]
        else:
            return tree

    def remove_pos_tuples(self, tree):
        """
        Function to check and remove tuples containing 'POS' and the smallEST tree containing the POS (i.e. NP: Cinderella's)
        INPUT:
            tree - tuple tree to process
        OUTPUT:
            list of tuple trees with 'POS' removed
        """

        # Apply the check and removal function to each top-level tuple
        #cleaned_tuples = [self.check_and_remove_PoS(t, PoS = 'POS') for t in tree if self.check_and_remove_PoS(t, PoS = 'POS') is not None]
        #cleaned_trees = [t for t in cleaned_tuples if t is not None]
        trees2compare = []
        for idx, t in enumerate(tree):
            if self.Does_Tree_Have_Target(t, target = ['POS']):
                trees2compare.append((idx, t))
        keep_trees = []
        if len(trees2compare) > 1:
            for idx, t1 in enumerate(trees2compare[:-1]):
                s1 = self.tree_to_list_of_strings(t1[1])
                for idy, t2 in enumerate(trees2compare[idx + 1:]):
                    s2 = self.tree_to_list_of_strings(t2[1])
                    if len(s1) < len(s2):
                        if self.is_sublist(s1, s2):
                            keep_trees.append(t2[0])
                    elif self.is_sublist(s2, s1):
                        keep_trees.append(t1[0])
        cleaned_trees = []
        for idx, t in enumerate(tree):
            if idx in keep_trees:
                cleaned_trees.append(t)
                    
        return cleaned_trees 

        # Filter out any None values that may have resulted from removal
        #return [t for t in cleaned_tuples if t is not None]
    
    def case_for_complicated_NP_embeddings(self, tree_list):
        """
        Combine NPs together into one NP to catch NNs that are modified by NPs 
        
        INPUT:
            tree_list - tuple tree
        OUTPUT:
            list of NPs that have passed this criterion
        """
        def check_for_NPs(tree_list, reduced_list):
            """
            Recursive function to perform logic on the tuple tree
            
            INPUT:
                tree_list - list of np trees to compare
                reduced_list - list of the list of final NP trees to keep
            OUTPUT:
                the list of NP strings to keep is updated in reduced_list
                the return value is the list of NP strings 
            """
            for tree in tree_list:
                #print(tree)
                if isinstance(tree, tuple):
                    keep_tree = True
                    count_of_NNs = self.count_tokens([tree], self.Noun_List)
                    #print("pass step 2")
                    #print("count of NNs: ", count_of_NNs)
                    if count_of_NNs > 1:
                        #print("pass step 3")
                        top_level_NPs = [[]] 
                        self.prune_general(tree[1][0], top_level_NPs)
                        #print(tree[1][0])
                        #print("top_level_NPs:",top_level_NPs[0])
                        count_of_NPs = self.count_tokens(tree[1], self.Noun_Phrases)
                        #print("count_of_NPs:",count_of_NPs)
                        if count_of_NPs > 1:
                            #print("pass step 4")
                            temp_list = []
                            for top_level_NP in top_level_NPs[0]:
                                #print("top_level_NPs:",top_level_NPs)
                                count_of_NNs = self.count_tokens(top_level_NP, self.Noun_List)
                                if count_of_NNs > 0:
                                    result = check_for_NPs([top_level_NP], reduced_list)  # Ensure this is a list
                                    temp_list.extend(result)  # Extend flattens the list, #look at flattening 
                            reduced_list[0].extend(temp_list)
                            keep_tree = False
                    if keep_tree:
                        reduced_list[0].append(tree)
                #return reduced_list[0] 
        NPs_that_pass_this_function = [[]]
        NP_check = check_for_NPs(tree_list, NPs_that_pass_this_function)
        return NPs_that_pass_this_function
     
    def count_tokens(self, tree_list, tokens): #this can count tokens, can be used when just wanting to find certain POS such as DET, CONJ, PP etc.
        """
        Count the number of tokens occuring in the tuple tree list
        
        INPUT:
            tree_list - the tupple tree list to be processed
            tokens - the list of tokens in the tuple_tree to be counted
        OUTPUT:
            the number of times the token occurs in the tree list            
        """
        count = 0
        for item in tree_list:
            if isinstance(item, tuple):
                tag, value = item
                if tag in tokens:
                    count += 1  # Increment count for each 'token'
                elif isinstance(value, list):
                    count += self.count_tokens(value, tokens)  # Recurse into nested lists
        return count

# %%
# Function to extract leaves from the tree
def extract_leaves(tree):
    leaves = []  # List to collect leaves

    def traverse(node):
        if isinstance(node, tuple) and isinstance(node[1], list):
            if all(isinstance(item, tuple) for item in node[1]):
                for item in node[1]:
                    traverse(item)
            else:
                leaves.extend([(node[0], subitem) for subitem in node[1]])
        elif isinstance(node, list):
            for subnode in node:
                traverse(subnode)

    traverse(tree)
    return leaves

def count_modifiers(leaves):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = All_Conjunctions + ["TO", "IN", "POS", "CD"]  # Include TO, IN, and POS in the exclusions
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals + ["been"]  # Include 'been' in the exclusions

    # Count modifiers that are not in the excluded lists
    modifier_count = 0
    for pos, word in leaves[:-1]:  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            modifier_count += 1

    return modifier_count
# List of POS tags and specific words to be considered or excluded
All_Nouns = ["NN", "NNS", "NNP", "NNPS"]
All_Adjectives = ["JJ", "JJR", "JJS", "PRP$"]
All_Adverbs = ["RB", "RBR", "RBS"]
All_Conjunctions = ["CC"]
Verbs_that_can_be_prenominal = ["VBN"]
Determiners_to_be_excluded_as_prenominals = ["a", "an", "the", "that", "these", "those", "this", "either"]
Words_to_be_excluded_as_prenominals = ["been"]


# Define the source and destination file paths
src_file_path = "C:\\Users\\james\\Documents\\Prenominal Modifiers\\Test Files\\Original\\Aer4zugl.cqp.AS_H.xlsx"
dest_file_path = "C:\\Users\\james\\Documents\\Prenominal Modifiers\\Test Files\\Modified\\Aer4zugl.cqp.AS_H.xlsx"

# Ensure the destination directory exists
os.makedirs(os.path.dirname(dest_file_path), exist_ok=True)


# Copy the file from source to destination
shutil.copy(src_file_path, dest_file_path)

# Load the copied Excel file into a DataFrame
data = pd.read_excel(dest_file_path)

# Insert a new blank column right after column 'A' titled 'Prenominal Modifiers'
data.insert(1, 'Prenominal Modifiers', '')

# Iterate over each row in the DataFrame
for index, row in data.iterrows():
    # Get the utterance from the 'UTTERANCES' column
    utterance = row['UTTERANCES']
    
    if pd.isna(utterance) or utterance.strip() == '':
        continue  # Skip this iteration if the cell is blank or empty
    
    print(f"Processing utterance: {utterance}")
    
    sentence_class = sentence_tree(utterance)
    sentence_class.prune_to_np_branches(sentence_class.parse_tuples)
    #sentence_class.prune_to_np_branches(sentence_class.indexed_tuples)
    nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])
    nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)
    total_modifiers = 0
    for tree in nps_factored_for_complicated_NP_embedding[0]:
        leaves = extract_leaves(tree)
        print("Leaves extracted from the tree:", leaves)
        
        # Count modifiers using the updated function
        modifier_count = count_modifiers(leaves)
        total_modifiers += modifier_count
        print(f"Modifiers for the last noun: {modifier_count}")
        print()

    
    
    data.at[index, 'Prenominal Modifiers'] = total_modifiers

# Ensure all entries in 'Prenominal Modifiers' are numeric, converting any non-numeric to NaN
data['Prenominal Modifiers'] = pd.to_numeric(data['Prenominal Modifiers'], errors='coerce')

# Replace NaNs with 0s (NaNs can result from non-numeric conversions)
data['Prenominal Modifiers'].fillna(0, inplace=True)


# Save the DataFrame to an Excel file
data.to_excel(dest_file_path, index=False)

# Open the Excel file with openpyxl to add a formula
wb = load_workbook(dest_file_path)
ws = wb.active

# Add a sum formula at the end of the data in column B
last_row = len(data) + 1  # +1 because DataFrame is zero-indexed and Excel is 1-indexed
ws[f'B{last_row}'] = f"=SUM(B2:B{last_row-1})"

# Add another formula in the next row in column B for division
next_row = last_row + 1
ws[f'B{next_row}'] = f"=B{last_row}/G{last_row}"
ws[f'A{next_row}'] = "Prenominal Modifiers/#Nouns"  # Place string in column A

# Save the changes
wb.save(dest_file_path)

print("DONE")

# %%
# Function to extract leaves from the tree
def extract_leaves(tree):
    leaves = []  # List to collect leaves

    def traverse(node):
        if isinstance(node, tuple) and isinstance(node[1], list):
            if all(isinstance(item, tuple) for item in node[1]):
                for item in node[1]:
                    traverse(item)
            else:
                leaves.extend([(node[0], subitem) for subitem in node[1]])
        elif isinstance(node, list):
            for subnode in node:
                traverse(subnode)

    traverse(tree)
    return leaves

"""
def count_modifiers(leaves):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC","TO", "IN", "POS", "DET"]  # Include TO, IN, and POS in the exclusions
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals + ["been"]  # Include 'been' in the exclusions

    # Count modifiers that are not in the excluded lists
    modifier_count = 0
    for pos, word in leaves[:-1]:  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            modifier_count += 1

    return modifier_count
"""

def scan_modifiers(leaves, special_phrases):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC", "TO", "IN", "POS", "CC", "RP", "PDT"]
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals  # Include 'been' in the exclusions
    CC_pos = ["CC"]

    # Add the specific prenominal quantifier phrases to exclude
    Prenominal_Quantifier_Words = ['many', 'all', 'most', 'some', 'few', 'several', 'number', 'bit', "lot","bunch", "any", "one"]

    # Count modifiers that are not in the excluded lists
    modifier_count = 0

    for ii, (pos, word) in enumerate(leaves[-2::-1]):  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            # Check for prenominal quantifier phrases
            if word in Prenominal_Quantifier_Words and ii + 1 < len(leaves) and leaves[-ii-2][1] == 'of':
                continue  # Skip the word if it is part of a prenominal quantifier phrase
            
            # Check if the current leaf contains a special phrase
            leaf_phrase = ' '.join(leaf[1] for leaf in leaves[-ii - 2:])
            if any(special_phrase in leaf_phrase for special_phrase in special_phrases):
                continue  # Skip if it matches any special phrase
            
            # Increment the modifier count
            modifier_count += 1

        if pos in CC_pos:
            if ii + 1 < len(leaves) and leaves[-ii-1][0] in All_Nouns:
                modifier_count -= 1
                continue
            elif ii + 2 < len(leaves) and leaves[-ii-2][0] == "DT":
                break

    return modifier_count



# List of POS tags and specific words to be considered or excluded
All_Nouns = ["NN", "NNS", "NNP", "NNPS"]
All_Adjectives = ["JJ", "JJR", "JJS", "PRP$"]
All_Adverbs = ["RB", "RBR", "RBS"]
Verbs_that_can_be_prenominal = ["VBN"]
Determiners_to_be_excluded_as_prenominals = ["a", "A", "an", "An", "the", "The", "that", "That", "these", "These", "those", "Those", "this", "This", "either", "Either", "around", "Around"]
Words_to_be_excluded_as_prenominals = ["been","around", "almost", "never","behind","above","whose","which"]
Prenominal_Quantifier_Phrases = ['a lot of', 'many of', 'all of', 'most of', 'some of', 'a few of', 'several of', 'a number of', 'a bit of', 'a bunch of', "any of", "one of"]




downloads_path = os.path.expanduser('~/Downloads')
# Define source directories and corresponding destination directories
directory_mapping = {
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\buggy sentences":r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\buggy sentences"}

# Ensure destination directories exist
for dest in directory_mapping.values():
    os.makedirs(dest, exist_ok=True)

def process_excel_file(src_file_path, dest_file_path, downloads_path):
    # Load the workbook and worksheet
    wb = load_workbook(src_file_path)
    ws = wb.active
    # Find the last row with data in column B
    last_row = ws.max_row
    for col in range(2, ws.max_column + 1):
        col_letter = get_column_letter(col)
        # Check if the header is "Comments"
        if ws[f'{col_letter}1'].value == "Comments":
            continue
        # Calculate the sum of values in the column (excluding the header)
        column_sum = 0
        for row in range(2, last_row + 1):
            cell_value = ws[f'{col_letter}{row}'].value
            if isinstance(cell_value, (int, float)):
                column_sum += cell_value
            elif cell_value == 'N/A':
                continue
        # Check if the last row contains a string that starts with "=SUM"
        last_row_value = ws[f'{col_letter}{last_row}'].value
        print("last_row_value:",last_row_value)
        if not isinstance(last_row_value, str) or not last_row_value.startswith("=SUM"):
            next_row = last_row + 1
            ws[f'{col_letter}{next_row}'] = column_sum
    
    # Save the file to the specified destination path
    wb.save(dest_file_path)
    
    # Save a copy to the Downloads folder
    downloads_dest_path = os.path.join(downloads_path, os.path.basename(dest_file_path))
    wb.save(downloads_dest_path)
    print(f"File saved to {dest_file_path} and {downloads_dest_path}")
    
    # Load the processed data into pandas for further manipulation
    data = pd.read_excel(dest_file_path)
    return data
    data.insert(1, 'Prenominal Modifiers', '')

    # Iterate over each row in the DataFrame
    for index, row in data.iterrows():
        # Get the utterance from the 'UTTERANCES' column
        utterance = row['UTTERANCES']
        
        if pd.isna(utterance) or utterance.strip() == '':
            continue  # Skip this iteration if the cell is blank or empty
        
        # Preprocess the utterance to remove specific substrings
        utterance = utterance.replace("[+ 0subj]", "").replace("[+ gram]", "").replace("0det","")
        
        print(f"Utterance: {utterance}")

        sentence_class = sentence_tree(utterance)
        special_phrase_count = sentence_class.handle_special_phrases(Prenominal_Quantifier_Phrases, utterance)
        sentence_class.prune_to_np_branches(sentence_class.parse_tuples)
        nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])
        nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)
        total_modifiers = 0
        for tree in nps_factored_for_complicated_NP_embedding[0]:
            leaves = extract_leaves(tree)
            
            # Count modifiers using the updated function
            modifier_count = scan_modifiers(leaves, Prenominal_Quantifier_Phrases)
            total_modifiers += modifier_count
            if modifier_count > 0:  # Change to >0 when debugging
                print()
                print("Extracted Phrase:", leaves)
                print(f"Prenominal No: {modifier_count}")
        total_modifiers += special_phrase_count
        print()
        print(f"Total No: {total_modifiers}")

        data.at[index, 'Prenominal Modifiers'] = total_modifiers

    # Ensure all entries in 'Prenominal Modifiers' are numeric, converting any non-numeric to NaN
    data['Prenominal Modifiers'] = pd.to_numeric(data['Prenominal Modifiers'], errors='coerce')

    # Replace NaNs with 0s (NaNs can result from non-numeric conversions)
    data['Prenominal Modifiers'].fillna(0, inplace=True)
    data.to_excel(dest_file_path, index=False)
    wb = load_workbook(dest_file_path)
    ws = wb.active
    last_row = len(data) + 1
    ws[f'B{last_row}'] = f"=SUM(B2:B{last_row-1})"
    next_row = last_row + 1
    ws[f'A{next_row}'] = "Prenominal Modifiers/#Nouns"
    ws[f'B{next_row}'] = f"=B{last_row}/G{last_row}"
    wb.save(dest_file_path)

# %%
# Function to extract leaves from the tree
def extract_leaves(tree):
    leaves = []  # List to collect leaves

    def traverse(node):
        if isinstance(node, tuple) and isinstance(node[1], list):
            if all(isinstance(item, tuple) for item in node[1]):
                for item in node[1]:
                    traverse(item)
            else:
                leaves.extend([(node[0], subitem) for subitem in node[1]])
        elif isinstance(node, list):
            for subnode in node:
                traverse(subnode)

    traverse(tree)
    return leaves

def count_modifiers(leaves):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC","TO", "IN", "POS", "DET"]  # Include TO, IN, and POS in the exclusions
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals + ["been"]  # Include 'been' in the exclusions

    # Count modifiers that are not in the excluded lists
    modifier_count = 0
    for pos, word in leaves[:-1]:  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            modifier_count += 1

    return modifier_count

def scan_modifiers(leaves):
    if not leaves or leaves[-1][0] not in All_Nouns:
        # If the last POS is not a noun, return 0
        return 0
    
    # Set up POS and words to exclude from counting
    excluded_pos = ["CC","TO", "IN", "POS", "DET"]  # Include TO, IN, and POS in the exclusions
    excluded_words = Determiners_to_be_excluded_as_prenominals + Words_to_be_excluded_as_prenominals + ["been"]  # Include 'been' in the exclusions
    CC_pos = ["CC"]

    # Count modifiers that are not in the excluded lists
    modifier_count = 0
    for ii, (pos,word) in enumerate(leaves[-1::-1]):  # Exclude the last leaf from counting
        if pos not in excluded_pos and word not in excluded_words:
            modifier_count += 1
        elif pos in CC_pos:
            if len(leaves-1)-ii-1 > 0:
                if leaves[len(leaves-1)-ii-1][0] in All_Nouns:
                    continue
            else:
                break
    return modifier_count

# List of POS tags and specific words to be considered or excluded
All_Nouns = ["NN", "NNS", "NNP", "NNPS", "CD"] #added CD for cases like the fare one, the bad one etc.
All_Adjectives = ["JJ", "JJR", "JJS", "PRP$"]
All_Adverbs = ["RB", "RBR", "RBS"]
Verbs_that_can_be_prenominal = ["VBN"]
Determiners_to_be_excluded_as_prenominals = ["a", "an", "the", "that", "these", "those", "this", "either"]
Words_to_be_excluded_as_prenominals = ["been"]







# Define source directories and corresponding destination directories
directory_mapping = {
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\older adult cinderella individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\older adult cinderella individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\older adult hobby individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\older adult hobby individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\young adult cinderella individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\young adult cinderella individual sentences",
    r"C:\Users\james\Documents\Prenominal Modifiers\CLAN QPA Output\young adult hobby individual sentences": r"C:\Users\james\Documents\Prenominal Modifiers\Program Processed\young adult hobby individual sentences"
}

# Ensure destination directories exist
for dest in directory_mapping.values():
    os.makedirs(dest, exist_ok=True)

def process_excel_file(src_file_path, dest_file_path):
    data = pd.read_excel(src_file_path)
    data.insert(1, 'Prenominal Modifiers', '')
    
    # Iterate over each row in the DataFrame
    for index, row in data.iterrows():
        # Get the utterance from the 'UTTERANCES' column
        utterance = row['UTTERANCES']

        if pd.isna(utterance) or utterance.strip() == '':
            continue  # Skip this iteration if the cell is blank or empty
        
        # Preprocess the utterance to remove specific substrings
        utterance = utterance.replace("[+ 0subj]", "").replace("[+ gram]", "").replace("0det","")
        
        print(f"Utterance: {utterance}")

        sentence_class = sentence_tree(utterance)
        sentence_class.prune_to_np_branches(sentence_class.parse_tuples)
        #sentence_class.prune_to_np_branches(sentence_class.indexed_tuples)
        nps_without_POS = sentence_class.remove_pos_tuples(sentence_class.prune_tree[0])
        nps_factored_for_complicated_NP_embedding = sentence_class.case_for_complicated_NP_embeddings(nps_without_POS)
        total_modifiers = 0
        for tree in nps_factored_for_complicated_NP_embedding[0]:
            leaves = extract_leaves(tree)
            print("Extracted Phrase:", leaves)

            # Count modifiers using the updated function
            modifier_count = scan_modifiers(leaves)
            total_modifiers += modifier_count
            print(f"Prenominal No: {modifier_count}")
            print()



        data.at[index, 'Prenominal Modifiers'] = total_modifiers

    # Ensure all entries in 'Prenominal Modifiers' are numeric, converting any non-numeric to NaN
    data['Prenominal Modifiers'] = pd.to_numeric(data['Prenominal Modifiers'], errors='coerce')

    # Replace NaNs with 0s (NaNs can result from non-numeric conversions)
    data['Prenominal Modifiers'].fillna(0, inplace=True)

    
    data.to_excel(dest_file_path, index=False)
    wb = load_workbook(dest_file_path)
    ws = wb.active
    last_row = len(data) + 1
    ws[f'B{last_row}'] = f"=SUM(B2:B{last_row-1})"
    next_row = last_row + 1
    ws[f'A{next_row}'] = "Prenominal Modifiers/#Nouns"
    ws[f'B{next_row}'] = f"=B{last_row}/G{last_row}"
    wb.save(dest_file_path)
